# %%
# !pip install --upgrade pip
# !pip install numpy
# !pip install tensorflow keras
# Out:
# Requirement already satisfied: pip in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (26.1.2)
# Requirement already satisfied: numpy in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (2.5.1)
# Requirement already satisfied: tensorflow in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (2.21.0)
# Requirement already satisfied: keras in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (3.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (26.2)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (7.35.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (2.34.2)
# Requirement already satisfied: setuptools in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (83.0.0)
# Requirement already satisfied: six>=1.12.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (4.16.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (1.82.1)
# Requirement already satisfied: numpy>=1.26.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (2.5.1)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (2026.6.17)
# Requirement already satisfied: rich in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from keras) (15.0.0)
# Requirement already satisfied: namex in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from keras) (0.1.0)
# Requirement already satisfied: optree in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from keras) (0.19.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from rich->keras) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from rich->keras) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
import sys, numpy as np
from keras.datasets import mnist
import matplotlib.pyplot as plt

(x_train, y_train), (x_test, y_test) = mnist.load_data()
# 255 is the maximum value of a pixel in an image. Dividing by 255 normalizes the pixel values to be between 0 and 1.
# each deata point is an pixel that has a value between 0 and 255, where 0 is black and 255 is white. By dividing by 255, we scale the pixel values to be between 0 and 1, which is a common practice in machine learning to improve convergence during training.
images, labels = (x_train[0:1000].reshape(1000, 28 * 28) / 255,
                  y_train[0:1000])
print(f"type(images)={type(images)}, type(labels)={type(labels)}")
print(f"images.shape={images.shape}, labels.shape={labels.shape}")

# 0,1,2,3,..,9
# 1000x10 matrix
one_hot_labels = np.zeros((len(labels), 10))
for i, label in enumerate(labels):
    one_hot_labels[i][label] = 1

# Goal Prediction: 0,1,2,3,..,9
labels = one_hot_labels

test_images = x_test.reshape(len(x_test), 28 * 28) / 255
test_labels = np.zeros((len(y_test), 10))
for i, label in enumerate(y_test):
    test_labels[i][label] = 1


def relu(x):
    return (x > 0) * x

def relu2derive(output):
    return output > 0

def tanh(x):
    return np.tanh(x)

def tanh2derive(output):
    return 1.0 - (output ** 2)

def softmax(x):
    temp = np.exp(x)
    return temp / np.sum(temp, axis=1, keepdims=True)

np.random.seed(1)

alpha, iterations, hidden_size = (0.005, 300, 40)
# 28x28 = 784
pixels_per_image, num_labels = (784, 10)

batch_size = 100

# -0.1 to 0.1
# 784x40 matrix
weights_0_1 = 0.02 * np.random.random((pixels_per_image, hidden_size)) - 0.01
# 40x10 matrix
weights_1_2 = 0.2 * np.random.random((hidden_size , num_labels)) - 0.1

print(f"weights_0_1.shape={weights_0_1.shape}, weights_1_2.shape={weights_1_2.shape}")
# print(f"weights_0_1=\n{weights_0_1}\nweights_1_2=\n{weights_1_2}")

# matlab
train_error = []
train_accuracy = []
test_error = []
test_accuracy = []

for j in range(iterations):
    train_err, train_acc = (0.0, 0)

    length = (int)(len(images) / batch_size)
    for i in range(length):
        batch_start, batch_end = ((i * batch_size), ((i + 1) * batch_size))

        # input layer is 1x784
        layer_0 = images[batch_start:batch_end]
        # hidden layer is 1x40
        ## 1x784 * 783x40 = 1x40
        layer_1 = relu(np.dot(layer_0, weights_0_1))

        # fill out 0 or 1 randomly for each element in dropou_mask , which has the same shape as layeer_1.
        # 0: disabled (dropout)
        # 1: enabled
        # dropout rate is 0.5 (50%)
        dropout_mask = np.random.randint(2, size=layer_1.shape)
        # retain the same expected value of the output by scaling the enabled neurons by 2 (1 / (1 - dropout_rate) = 1 / (1 - 0.5) = 2)
        layer_1 *= dropout_mask * 2

        # prediction layer is 1x10
        # 1x40 * 40x10 = 1x10
        layer_2 = softmax(np.dot(layer_1, weights_1_2))

        goal_prediction = labels[batch_start:batch_end]
        train_err += np.sum((layer_2 - goal_prediction) ** 2)

        for k in range(batch_size):
            goal_prediction = labels[batch_start + k:batch_start + k + 1]
            train_acc += int(np.argmax(layer_2[k:k+1]) == np.argmax(goal_prediction))

        layer_2_delta = layer_2 - labels[batch_start:batch_end]
        layer_1_delta = layer_2_delta.dot(weights_1_2.T) * relu2derive(layer_1)
        layer_1_delta *= dropout_mask

        weights_1_2 = weights_1_2 - alpha * layer_1.T.dot(layer_2_delta)
        weights_0_1 = weights_0_1 - alpha * layer_0.T.dot(layer_1_delta)

    # str()[0:5] is used to limit the number of characters displayed for the training error, making the output more concise and easier to read. It effectively truncates the string representation of the training error to the first 5 characters, which typically includes the most significant digits.
    # print("Train-Err=" + str(train_err / float(len(images)))[0:5])
    #train_error.append(train_err / float(len(images)))
    #train_accuracy.append(train_acc / float(len(images)))


#    if( j % 10 == 0 or j == iterations - 1):
    test_err, test_acc = (0.0, 0)

    for i in range(len(test_images)):
        layer_0 = test_images[i:i+1]
        layer_1 = relu(np.dot(layer_0, weights_0_1))
        layer_2 = softmax(np.dot(layer_1, weights_1_2))

        test_err += np.sum((layer_2 - test_labels[i:i+1]) ** 2)
        test_acc += int(np.argmax(layer_2) == np.argmax(test_labels[i:i+1]))

    sys.stdout.write(
        " I:" + str(j) + \
        " Train-Acc:" + str(train_acc / float(len(images)))[0:5] + \
        " Test-Acc:" + str(test_acc / float(len(test_images)))[0:5]
    )
    sys.stdout.write("\n")

    # matplotlib
    train_accuracy.append(train_acc / float(len(images)))
    test_accuracy.append(test_acc / float(len(test_images)))

plt.figure(figsize=(8, 4))
plt.plot(train_accuracy, label="Train-Acc")
plt.plot(test_accuracy, label="Test-Acc")
plt.xlabel("Iterations")
plt.ylabel("Value")
plt.title("Training History over Iterations")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# type(images)=<class 'numpy.ndarray'>, type(labels)=<class 'numpy.ndarray'>
# images.shape=(1000, 784), labels.shape=(1000,)
# weights_0_1.shape=(784, 40), weights_1_2.shape=(40, 10)
#  I:0 Train-Acc:0.292 Test-Acc:0.520
#  I:1 Train-Acc:0.474 Test-Acc:0.603
#  I:2 Train-Acc:0.583 Test-Acc:0.706
#  I:3 Train-Acc:0.66 Test-Acc:0.774
#  I:4 Train-Acc:0.706 Test-Acc:0.772
#  I:5 Train-Acc:0.731 Test-Acc:0.788
#  I:6 Train-Acc:0.779 Test-Acc:0.800
#  I:7 Train-Acc:0.784 Test-Acc:0.824
#  I:8 Train-Acc:0.792 Test-Acc:0.825
#  I:9 Train-Acc:0.816 Test-Acc:0.842
#  I:10 Train-Acc:0.824 Test-Acc:0.839
#  I:11 Train-Acc:0.839 Test-Acc:0.848
#  I:12 Train-Acc:0.834 Test-Acc:0.836
#  I:13 Train-Acc:0.841 Test-Acc:0.845
#  I:14 Train-Acc:0.856 Test-Acc:0.861
#  I:15 Train-Acc:0.853 Test-Acc:0.851
#  I:16 Train-Acc:0.877 Test-Acc:0.855
#  I:17 Train-Acc:0.875 Test-Acc:0.864
#  I:18 Train-Acc:0.871 Test-Acc:0.848
#  I:19 Train-Acc:0.885 Test-Acc:0.849
#  I:20 Train-Acc:0.884 Test-Acc:0.857
#  I:21 Train-Acc:0.886 Test-Acc:0.868
#  I:22 Train-Acc:0.894 Test-Acc:0.869
#  I:23 Train-Acc:0.894 Test-Acc:0.865
#  I:24 Train-Acc:0.899 Test-Acc:0.870
#  I:25 Train-Acc:0.888 Test-Acc:0.867
#  I:26 Train-Acc:0.903 Test-Acc:0.862
#  I:27 Train-Acc:0.906 Test-Acc:0.867
#  I:28 Train-Acc:0.9 Test-Acc:0.867
#  I:29 Train-Acc:0.902 Test-Acc:0.869
#  I:30 Train-Acc:0.909 Test-Acc:0.876
#  I:31 Train-Acc:0.91 Test-Acc:0.868
#  I:32 Train-Acc:0.898 Test-Acc:0.867
#  I:33 Train-Acc:0.909 Test-Acc:0.869
#  I:34 Train-Acc:0.923 Test-Acc:0.867
#  I:35 Train-Acc:0.912 Test-Acc:0.865
#  I:36 Train-Acc:0.916 Test-Acc:0.868
#  I:37 Train-Acc:0.932 Test-Acc:0.869
#  I:38 Train-Acc:0.92 Test-Acc:0.868
#  I:39 Train-Acc:0.927 Test-Acc:0.872
#  I:40 Train-Acc:0.926 Test-Acc:0.865
#  I:41 Train-Acc:0.938 Test-Acc:0.870
#  I:42 Train-Acc:0.926 Test-Acc:0.869
#  I:43 Train-Acc:0.929 Test-Acc:0.870
#  I:44 Train-Acc:0.925 Test-Acc:0.869
#  I:45 Train-Acc:0.94 Test-Acc:0.868
#  I:46 Train-Acc:0.936 Test-Acc:0.867
#  I:47 Train-Acc:0.943 Test-Acc:0.870
#  I:48 Train-Acc:0.937 Test-Acc:0.873
#  I:49 Train-Acc:0.951 Test-Acc:0.871
#  I:50 Train-Acc:0.943 Test-Acc:0.871
#  I:51 Train-Acc:0.918 Test-Acc:0.868
#  I:52 Train-Acc:0.939 Test-Acc:0.868
#  I:53 Train-Acc:0.933 Test-Acc:0.869
#  I:54 Train-Acc:0.947 Test-Acc:0.864
#  I:55 Train-Acc:0.942 Test-Acc:0.872
#  I:56 Train-Acc:0.952 Test-Acc:0.869
#  I:57 Train-Acc:0.93 Test-Acc:0.865
#  I:58 Train-Acc:0.949 Test-Acc:0.870
#  I:59 Train-Acc:0.95 Test-Acc:0.868
#  I:60 Train-Acc:0.936 Test-Acc:0.869
#  I:61 Train-Acc:0.943 Test-Acc:0.871
#  I:62 Train-Acc:0.947 Test-Acc:0.868
#  I:63 Train-Acc:0.944 Test-Acc:0.870
#  I:64 Train-Acc:0.951 Test-Acc:0.866
#  I:65 Train-Acc:0.948 Test-Acc:0.871
#  I:66 Train-Acc:0.953 Test-Acc:0.873
#  I:67 Train-Acc:0.942 Test-Acc:0.870
#  I:68 Train-Acc:0.959 Test-Acc:0.871
#  I:69 Train-Acc:0.963 Test-Acc:0.870
#  I:70 Train-Acc:0.945 Test-Acc:0.863
#  I:71 Train-Acc:0.951 Test-Acc:0.871
#  I:72 Train-Acc:0.955 Test-Acc:0.868
#  I:73 Train-Acc:0.967 Test-Acc:0.868
#  I:74 Train-Acc:0.967 Test-Acc:0.870
#  I:75 Train-Acc:0.957 Test-Acc:0.871
#  I:76 Train-Acc:0.953 Test-Acc:0.875
#  I:77 Train-Acc:0.957 Test-Acc:0.869
#  I:78 Train-Acc:0.962 Test-Acc:0.867
#  I:79 Train-Acc:0.964 Test-Acc:0.870
#  I:80 Train-Acc:0.956 Test-Acc:0.871
#  I:81 Train-Acc:0.953 Test-Acc:0.871
#  I:82 Train-Acc:0.967 Test-Acc:0.871
#  I:83 Train-Acc:0.952 Test-Acc:0.873
#  I:84 Train-Acc:0.951 Test-Acc:0.872
#  I:85 Train-Acc:0.961 Test-Acc:0.868
#  I:86 Train-Acc:0.962 Test-Acc:0.868
#  I:87 Train-Acc:0.959 Test-Acc:0.872
#  I:88 Train-Acc:0.963 Test-Acc:0.870
#  I:89 Train-Acc:0.963 Test-Acc:0.870
#  I:90 Train-Acc:0.965 Test-Acc:0.868
#  I:91 Train-Acc:0.957 Test-Acc:0.873
#  I:92 Train-Acc:0.963 Test-Acc:0.870
#  I:93 Train-Acc:0.951 Test-Acc:0.869
#  I:94 Train-Acc:0.967 Test-Acc:0.871
#  I:95 Train-Acc:0.959 Test-Acc:0.865
#  I:96 Train-Acc:0.97 Test-Acc:0.867
#  I:97 Train-Acc:0.964 Test-Acc:0.872
#  I:98 Train-Acc:0.97 Test-Acc:0.867
#  I:99 Train-Acc:0.963 Test-Acc:0.868
#  I:100 Train-Acc:0.959 Test-Acc:0.868
#  I:101 Train-Acc:0.967 Test-Acc:0.866
#  I:102 Train-Acc:0.964 Test-Acc:0.867
#  I:103 Train-Acc:0.98 Test-Acc:0.872
#  I:104 Train-Acc:0.964 Test-Acc:0.868
#  I:105 Train-Acc:0.959 Test-Acc:0.869
#  I:106 Train-Acc:0.959 Test-Acc:0.871
#  I:107 Train-Acc:0.969 Test-Acc:0.866
#  I:108 Train-Acc:0.971 Test-Acc:0.866
#  I:109 Train-Acc:0.972 Test-Acc:0.873
#  I:110 Train-Acc:0.964 Test-Acc:0.864
#  I:111 Train-Acc:0.962 Test-Acc:0.864
#  I:112 Train-Acc:0.97 Test-Acc:0.870
#  I:113 Train-Acc:0.965 Test-Acc:0.865
#  I:114 Train-Acc:0.971 Test-Acc:0.872
#  I:115 Train-Acc:0.976 Test-Acc:0.874
#  I:116 Train-Acc:0.974 Test-Acc:0.872
#  I:117 Train-Acc:0.975 Test-Acc:0.870
#  I:118 Train-Acc:0.974 Test-Acc:0.868
#  I:119 Train-Acc:0.964 Test-Acc:0.869
#  I:120 Train-Acc:0.967 Test-Acc:0.875
#  I:121 Train-Acc:0.97 Test-Acc:0.870
#  I:122 Train-Acc:0.972 Test-Acc:0.869
#  I:123 Train-Acc:0.975 Test-Acc:0.870
#  I:124 Train-Acc:0.979 Test-Acc:0.869
#  I:125 Train-Acc:0.969 Test-Acc:0.867
#  I:126 Train-Acc:0.96 Test-Acc:0.869
#  I:127 Train-Acc:0.962 Test-Acc:0.867
#  I:128 Train-Acc:0.964 Test-Acc:0.867
#  I:129 Train-Acc:0.967 Test-Acc:0.868
#  I:130 Train-Acc:0.969 Test-Acc:0.868
#  I:131 Train-Acc:0.972 Test-Acc:0.870
#  I:132 Train-Acc:0.963 Test-Acc:0.870
#  I:133 Train-Acc:0.973 Test-Acc:0.865
#  I:134 Train-Acc:0.976 Test-Acc:0.867
#  I:135 Train-Acc:0.972 Test-Acc:0.869
#  I:136 Train-Acc:0.966 Test-Acc:0.869
#  I:137 Train-Acc:0.967 Test-Acc:0.867
#  I:138 Train-Acc:0.971 Test-Acc:0.869
#  I:139 Train-Acc:0.973 Test-Acc:0.866
#  I:140 Train-Acc:0.972 Test-Acc:0.869
#  I:141 Train-Acc:0.975 Test-Acc:0.867
#  I:142 Train-Acc:0.966 Test-Acc:0.863
#  I:143 Train-Acc:0.97 Test-Acc:0.864
#  I:144 Train-Acc:0.974 Test-Acc:0.869
#  I:145 Train-Acc:0.97 Test-Acc:0.866
#  I:146 Train-Acc:0.964 Test-Acc:0.867
#  I:147 Train-Acc:0.969 Test-Acc:0.870
#  I:148 Train-Acc:0.975 Test-Acc:0.866
#  I:149 Train-Acc:0.964 Test-Acc:0.871
#  I:150 Train-Acc:0.976 Test-Acc:0.870
#  I:151 Train-Acc:0.966 Test-Acc:0.870
#  I:152 Train-Acc:0.976 Test-Acc:0.869
#  I:153 Train-Acc:0.96 Test-Acc:0.867
#  I:154 Train-Acc:0.973 Test-Acc:0.865
#  I:155 Train-Acc:0.966 Test-Acc:0.863
#  I:156 Train-Acc:0.976 Test-Acc:0.868
#  I:157 Train-Acc:0.974 Test-Acc:0.866
#  I:158 Train-Acc:0.971 Test-Acc:0.869
#  I:159 Train-Acc:0.967 Test-Acc:0.867
#  I:160 Train-Acc:0.975 Test-Acc:0.868
#  I:161 Train-Acc:0.971 Test-Acc:0.868
#  I:162 Train-Acc:0.976 Test-Acc:0.87
#  I:163 Train-Acc:0.971 Test-Acc:0.866
#  I:164 Train-Acc:0.973 Test-Acc:0.868
#  I:165 Train-Acc:0.971 Test-Acc:0.866
#  I:166 Train-Acc:0.976 Test-Acc:0.866
#  I:167 Train-Acc:0.975 Test-Acc:0.865
#  I:168 Train-Acc:0.976 Test-Acc:0.864
#  I:169 Train-Acc:0.975 Test-Acc:0.866
#  I:170 Train-Acc:0.975 Test-Acc:0.865
#  I:171 Train-Acc:0.985 Test-Acc:0.867
#  I:172 Train-Acc:0.979 Test-Acc:0.867
#  I:173 Train-Acc:0.979 Test-Acc:0.865
#  I:174 Train-Acc:0.972 Test-Acc:0.870
#  I:175 Train-Acc:0.979 Test-Acc:0.869
#  I:176 Train-Acc:0.978 Test-Acc:0.870
#  I:177 Train-Acc:0.962 Test-Acc:0.870
#  I:178 Train-Acc:0.976 Test-Acc:0.872
#  I:179 Train-Acc:0.981 Test-Acc:0.866
#  I:180 Train-Acc:0.97 Test-Acc:0.866
#  I:181 Train-Acc:0.975 Test-Acc:0.869
#  I:182 Train-Acc:0.977 Test-Acc:0.870
#  I:183 Train-Acc:0.982 Test-Acc:0.867
#  I:184 Train-Acc:0.98 Test-Acc:0.868
#  I:185 Train-Acc:0.978 Test-Acc:0.864
#  I:186 Train-Acc:0.972 Test-Acc:0.862
#  I:187 Train-Acc:0.977 Test-Acc:0.867
#  I:188 Train-Acc:0.978 Test-Acc:0.866
#  I:189 Train-Acc:0.967 Test-Acc:0.865
#  I:190 Train-Acc:0.975 Test-Acc:0.868
#  I:191 Train-Acc:0.974 Test-Acc:0.863
#  I:192 Train-Acc:0.98 Test-Acc:0.865
#  I:193 Train-Acc:0.979 Test-Acc:0.861
#  I:194 Train-Acc:0.972 Test-Acc:0.868
#  I:195 Train-Acc:0.976 Test-Acc:0.863
#  I:196 Train-Acc:0.969 Test-Acc:0.864
#  I:197 Train-Acc:0.971 Test-Acc:0.865
#  I:198 Train-Acc:0.972 Test-Acc:0.864
#  I:199 Train-Acc:0.979 Test-Acc:0.860
#  I:200 Train-Acc:0.983 Test-Acc:0.87
#  I:201 Train-Acc:0.976 Test-Acc:0.862
#  I:202 Train-Acc:0.977 Test-Acc:0.865
#  I:203 Train-Acc:0.979 Test-Acc:0.867
#  I:204 Train-Acc:0.975 Test-Acc:0.869
#  I:205 Train-Acc:0.982 Test-Acc:0.865
#  I:206 Train-Acc:0.981 Test-Acc:0.866
#  I:207 Train-Acc:0.98 Test-Acc:0.868
#  I:208 Train-Acc:0.978 Test-Acc:0.866
#  I:209 Train-Acc:0.984 Test-Acc:0.870
#  I:210 Train-Acc:0.977 Test-Acc:0.867
#  I:211 Train-Acc:0.981 Test-Acc:0.866
#  I:212 Train-Acc:0.98 Test-Acc:0.868
#  I:213 Train-Acc:0.973 Test-Acc:0.866
#  I:214 Train-Acc:0.979 Test-Acc:0.868
#  I:215 Train-Acc:0.982 Test-Acc:0.868
#  I:216 Train-Acc:0.982 Test-Acc:0.868
#  I:217 Train-Acc:0.98 Test-Acc:0.867
#  I:218 Train-Acc:0.966 Test-Acc:0.867
#  I:219 Train-Acc:0.977 Test-Acc:0.868
#  I:220 Train-Acc:0.972 Test-Acc:0.868
#  I:221 Train-Acc:0.974 Test-Acc:0.867
#  I:222 Train-Acc:0.978 Test-Acc:0.869
#  I:223 Train-Acc:0.982 Test-Acc:0.865
#  I:224 Train-Acc:0.968 Test-Acc:0.865
#  I:225 Train-Acc:0.976 Test-Acc:0.867
#  I:226 Train-Acc:0.969 Test-Acc:0.870
#  I:227 Train-Acc:0.972 Test-Acc:0.867
#  I:228 Train-Acc:0.982 Test-Acc:0.872
#  I:229 Train-Acc:0.978 Test-Acc:0.865
#  I:230 Train-Acc:0.985 Test-Acc:0.868
#  I:231 Train-Acc:0.98 Test-Acc:0.864
#  I:232 Train-Acc:0.978 Test-Acc:0.866
#  I:233 Train-Acc:0.979 Test-Acc:0.870
#  I:234 Train-Acc:0.976 Test-Acc:0.868
#  I:235 Train-Acc:0.994 Test-Acc:0.87
#  I:236 Train-Acc:0.983 Test-Acc:0.871
#  I:237 Train-Acc:0.982 Test-Acc:0.866
#  I:238 Train-Acc:0.975 Test-Acc:0.866
#  I:239 Train-Acc:0.98 Test-Acc:0.867
#  I:240 Train-Acc:0.98 Test-Acc:0.864
#  I:241 Train-Acc:0.979 Test-Acc:0.866
#  I:242 Train-Acc:0.976 Test-Acc:0.865
#  I:243 Train-Acc:0.972 Test-Acc:0.865
#  I:244 Train-Acc:0.976 Test-Acc:0.866
#  I:245 Train-Acc:0.977 Test-Acc:0.867
#  I:246 Train-Acc:0.973 Test-Acc:0.867
#  I:247 Train-Acc:0.976 Test-Acc:0.867
#  I:248 Train-Acc:0.983 Test-Acc:0.864
#  I:249 Train-Acc:0.984 Test-Acc:0.867
#  I:250 Train-Acc:0.988 Test-Acc:0.864
#  I:251 Train-Acc:0.982 Test-Acc:0.867
#  I:252 Train-Acc:0.978 Test-Acc:0.868
#  I:253 Train-Acc:0.978 Test-Acc:0.865
#  I:254 Train-Acc:0.973 Test-Acc:0.867
#  I:255 Train-Acc:0.981 Test-Acc:0.866
#  I:256 Train-Acc:0.973 Test-Acc:0.869
#  I:257 Train-Acc:0.977 Test-Acc:0.867
#  I:258 Train-Acc:0.972 Test-Acc:0.866
#  I:259 Train-Acc:0.974 Test-Acc:0.866
#  I:260 Train-Acc:0.987 Test-Acc:0.868
#  I:261 Train-Acc:0.975 Test-Acc:0.867
#  I:262 Train-Acc:0.98 Test-Acc:0.865
#  I:263 Train-Acc:0.977 Test-Acc:0.869
#  I:264 Train-Acc:0.977 Test-Acc:0.866
#  I:265 Train-Acc:0.976 Test-Acc:0.867
#  I:266 Train-Acc:0.988 Test-Acc:0.866
#  I:267 Train-Acc:0.98 Test-Acc:0.865
#  I:268 Train-Acc:0.974 Test-Acc:0.867
#  I:269 Train-Acc:0.98 Test-Acc:0.864
#  I:270 Train-Acc:0.985 Test-Acc:0.862
#  I:271 Train-Acc:0.98 Test-Acc:0.867
#  I:272 Train-Acc:0.983 Test-Acc:0.864
#  I:273 Train-Acc:0.98 Test-Acc:0.863
#  I:274 Train-Acc:0.981 Test-Acc:0.867
#  I:275 Train-Acc:0.984 Test-Acc:0.864
#  I:276 Train-Acc:0.972 Test-Acc:0.862
#  I:277 Train-Acc:0.981 Test-Acc:0.863
#  I:278 Train-Acc:0.977 Test-Acc:0.866
#  I:279 Train-Acc:0.981 Test-Acc:0.864
#  I:280 Train-Acc:0.978 Test-Acc:0.863
#  I:281 Train-Acc:0.971 Test-Acc:0.864
#  I:282 Train-Acc:0.983 Test-Acc:0.864
#  I:283 Train-Acc:0.982 Test-Acc:0.860
#  I:284 Train-Acc:0.972 Test-Acc:0.864
#  I:285 Train-Acc:0.983 Test-Acc:0.865
#  I:286 Train-Acc:0.985 Test-Acc:0.864
#  I:287 Train-Acc:0.979 Test-Acc:0.863
#  I:288 Train-Acc:0.985 Test-Acc:0.863
#  I:289 Train-Acc:0.982 Test-Acc:0.861
#  I:290 Train-Acc:0.98 Test-Acc:0.867
#  I:291 Train-Acc:0.975 Test-Acc:0.868
#  I:292 Train-Acc:0.976 Test-Acc:0.863
#  I:293 Train-Acc:0.978 Test-Acc:0.867
#  I:294 Train-Acc:0.984 Test-Acc:0.865
#  I:295 Train-Acc:0.979 Test-Acc:0.867
#  I:296 Train-Acc:0.979 Test-Acc:0.864
#  I:297 Train-Acc:0.983 Test-Acc:0.866
#  I:298 Train-Acc:0.979 Test-Acc:0.867
#  I:299 Train-Acc:0.974 Test-Acc:0.866
