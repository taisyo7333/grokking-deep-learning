# %%
# !pip install --upgrade pip
# !pip install numpy
# !pip install tensorflow keras
# Out:
# Requirement already satisfied: pip in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (26.1.2)
# Requirement already satisfied: numpy in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (2.5.1)
# Requirement already satisfied: tensorflow in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (2.21.0)
# Requirement already satisfied: keras in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (3.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (26.2)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (7.35.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (2.34.2)
# Requirement already satisfied: setuptools in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (83.0.0)
# Requirement already satisfied: six>=1.12.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (4.16.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (1.82.1)
# Requirement already satisfied: numpy>=1.26.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (2.5.1)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (2026.6.17)
# Requirement already satisfied: rich in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from keras) (15.0.0)
# Requirement already satisfied: namex in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from keras) (0.1.0)
# Requirement already satisfied: optree in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from keras) (0.19.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from rich->keras) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from rich->keras) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
import sys, numpy as np
from keras.datasets import mnist
import matplotlib.pyplot as plt

(x_train, y_train), (x_test, y_test) = mnist.load_data()
# 255 is the maximum value of a pixel in an image. Dividing by 255 normalizes the pixel values to be between 0 and 1.
# each deata point is an pixel that has a value between 0 and 255, where 0 is black and 255 is white. By dividing by 255, we scale the pixel values to be between 0 and 1, which is a common practice in machine learning to improve convergence during training.
images, labels = (x_train[0:1000].reshape(1000, 28 * 28) / 255,
                  y_train[0:1000])
print(f"type(images)={type(images)}, type(labels)={type(labels)}")
print(f"images.shape={images.shape}, labels.shape={labels.shape}")

# 0,1,2,3,..,9
# 1000x10 matrix
one_hot_labels = np.zeros((len(labels), 10))
for i, label in enumerate(labels):
    one_hot_labels[i][label] = 1

# Goal Prediction: 0,1,2,3,..,9
labels = one_hot_labels

test_images = x_test.reshape(len(x_test), 28 * 28) / 255
test_labels = np.zeros((len(y_test), 10))
for i, label in enumerate(y_test):
    test_labels[i][label] = 1


def relu(x):
    return (x > 0) * x

def relu2derive(output):
    return output > 0

def tanh(x):
    return np.tanh(x)

def tanh2derive(output):
    return 1 - (output ** 2)

def softmax(x):
    temp = np.exp(x)
    return temp / np.sum(temp, axis=1, keepdims=True)

np.random.seed(1)

alpha, iterations, hidden_size = (0.005, 300, 40)
# 28x28 = 784
pixels_per_image, num_labels = (784, 10)

batch_size = 100

# -0.1 to 0.1
# 784x40 matrix
weights_0_1 = 0.02 * np.random.random((pixels_per_image, hidden_size)) - 0.01
# 40x10 matrix
weights_1_2 = 0.2 * np.random.random((hidden_size , num_labels)) - 0.1

print(f"weights_0_1.shape={weights_0_1.shape}, weights_1_2.shape={weights_1_2.shape}")
# print(f"weights_0_1=\n{weights_0_1}\nweights_1_2=\n{weights_1_2}")

# matlab
train_error = []
train_accuracy = []
test_error = []
test_accuracy = []

for j in range(iterations):
    train_err, train_acc = (0.0, 0)

    length = (int)(len(images) / batch_size)
    for i in range(length):
        batch_start, batch_end = ((i * batch_size), ((i + 1) * batch_size))

        # input layer is 1x784
        layer_0 = images[batch_start:batch_end]
        # hidden layer is 1x40
        ## 1x784 * 783x40 = 1x40
        layer_1 = relu(np.dot(layer_0, weights_0_1))

        # fill out 0 or 1 randomly for each element in dropou_mask , which has the same shape as layeer_1.
        # 0: disabled (dropout)
        # 1: enabled
        # dropout rate is 0.5 (50%)
        dropout_mask = np.random.randint(2, size=layer_1.shape)
        # retain the same expected value of the output by scaling the enabled neurons by 2 (1 / (1 - dropout_rate) = 1 / (1 - 0.5) = 2)
        layer_1 *= dropout_mask * 2

        # prediction layer is 1x10
        # 1x40 * 40x10 = 1x10
        layer_2 = np.dot(layer_1, weights_1_2)

        goal_prediction = labels[batch_start:batch_end]
        train_err += np.sum((layer_2 - goal_prediction) ** 2)

        for k in range(batch_size):
            goal_prediction = labels[batch_start + k:batch_start + k + 1]
            train_acc += int(np.argmax(layer_2[k:k+1]) == np.argmax(goal_prediction))

        layer_2_delta = layer_2 - labels[batch_start:batch_end]
        layer_1_delta = layer_2_delta.dot(weights_1_2.T) * relu2derive(layer_1)
        layer_1_delta *= dropout_mask

        weights_1_2 = weights_1_2 - alpha * layer_1.T.dot(layer_2_delta)
        weights_0_1 = weights_0_1 - alpha * layer_0.T.dot(layer_1_delta)

    # str()[0:5] is used to limit the number of characters displayed for the training error, making the output more concise and easier to read. It effectively truncates the string representation of the training error to the first 5 characters, which typically includes the most significant digits.
    # print("Train-Err=" + str(train_err / float(len(images)))[0:5])
    #train_error.append(train_err / float(len(images)))
    #train_accuracy.append(train_acc / float(len(images)))


#    if( j % 10 == 0 or j == iterations - 1):
    test_err, test_acc = (0.0, 0)

    for i in range(len(test_images)):
        layer_0 = test_images[i:i+1]
        layer_1 = relu(np.dot(layer_0, weights_0_1))
        layer_2 = np.dot(layer_1, weights_1_2)

        test_err += np.sum((layer_2 - test_labels[i:i+1]) ** 2)
        test_acc += int(np.argmax(layer_2) == np.argmax(test_labels[i:i+1]))

    sys.stdout.write(
        " I:" + str(j) + \
        " Train-Err:" + str(train_err / float(len(images)))[0:5] + \
        " Train-Acc:" + str(train_acc / float(len(images)))[0:5] + \
        " Test-Err:" + str(test_err / float(len(test_images)))[0:5] + \
        " Test-Acc:" + str(test_acc / float(len(test_images)))[0:5]
    )
    sys.stdout.write("\n")

    # matplotlib
    train_error.append(train_err / float(len(images)))
    train_accuracy.append(train_acc / float(len(images)))
    test_error.append(test_err / float(len(test_images)))
    test_accuracy.append(test_acc / float(len(test_images)))

plt.figure(figsize=(8, 4))
plt.plot(train_error, label="Train-Err")
plt.plot(train_accuracy, label="Train-Acc")
plt.plot(test_error, label="Test-Err")
plt.plot(test_accuracy, label="Test-Acc")
plt.xlabel("Iterations")
plt.ylabel("Value")
plt.title("Training History over Iterations")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# type(images)=<class 'numpy.ndarray'>, type(labels)=<class 'numpy.ndarray'>
# images.shape=(1000, 784), labels.shape=(1000,)
# weights_0_1.shape=(784, 40), weights_1_2.shape=(40, 10)
#  I:0 Train-Err:0.887 Train-Acc:0.27 Test-Err:0.735 Test-Acc:0.508
#  I:1 Train-Err:0.716 Train-Acc:0.526 Test-Err:0.648 Test-Acc:0.551
#  I:2 Train-Err:0.645 Train-Acc:0.595 Test-Err:0.560 Test-Acc:0.657
#  I:3 Train-Err:0.596 Train-Acc:0.634 Test-Err:0.490 Test-Acc:0.727
#  I:4 Train-Err:0.552 Train-Acc:0.692 Test-Err:0.473 Test-Acc:0.78
#  I:5 Train-Err:0.537 Train-Acc:0.693 Test-Err:0.455 Test-Acc:0.793
#  I:6 Train-Err:0.499 Train-Acc:0.743 Test-Err:0.437 Test-Acc:0.807
#  I:7 Train-Err:0.491 Train-Acc:0.741 Test-Err:0.403 Test-Acc:0.826
#  I:8 Train-Err:0.470 Train-Acc:0.76 Test-Err:0.381 Test-Acc:0.84
#  I:9 Train-Err:0.466 Train-Acc:0.777 Test-Err:0.371 Test-Acc:0.823
#  I:10 Train-Err:0.452 Train-Acc:0.782 Test-Err:0.380 Test-Acc:0.840
#  I:11 Train-Err:0.440 Train-Acc:0.78 Test-Err:0.358 Test-Acc:0.843
#  I:12 Train-Err:0.426 Train-Acc:0.799 Test-Err:0.359 Test-Acc:0.835
#  I:13 Train-Err:0.434 Train-Acc:0.778 Test-Err:0.358 Test-Acc:0.842
#  I:14 Train-Err:0.424 Train-Acc:0.802 Test-Err:0.344 Test-Acc:0.844
#  I:15 Train-Err:0.404 Train-Acc:0.815 Test-Err:0.349 Test-Acc:0.837
#  I:16 Train-Err:0.403 Train-Acc:0.818 Test-Err:0.333 Test-Acc:0.865
#  I:17 Train-Err:0.408 Train-Acc:0.808 Test-Err:0.336 Test-Acc:0.866
#  I:18 Train-Err:0.402 Train-Acc:0.818 Test-Err:0.361 Test-Acc:0.846
#  I:19 Train-Err:0.370 Train-Acc:0.851 Test-Err:0.357 Test-Acc:0.845
#  I:20 Train-Err:0.378 Train-Acc:0.836 Test-Err:0.312 Test-Acc:0.869
#  I:21 Train-Err:0.393 Train-Acc:0.82 Test-Err:0.345 Test-Acc:0.858
#  I:22 Train-Err:0.380 Train-Acc:0.835 Test-Err:0.323 Test-Acc:0.86
#  I:23 Train-Err:0.385 Train-Acc:0.844 Test-Err:0.323 Test-Acc:0.860
#  I:24 Train-Err:0.377 Train-Acc:0.85 Test-Err:0.321 Test-Acc:0.862
#  I:25 Train-Err:0.386 Train-Acc:0.822 Test-Err:0.328 Test-Acc:0.851
#  I:26 Train-Err:0.376 Train-Acc:0.852 Test-Err:0.327 Test-Acc:0.860
#  I:27 Train-Err:0.360 Train-Acc:0.855 Test-Err:0.352 Test-Acc:0.855
#  I:28 Train-Err:0.367 Train-Acc:0.833 Test-Err:0.315 Test-Acc:0.858
#  I:29 Train-Err:0.353 Train-Acc:0.844 Test-Err:0.301 Test-Acc:0.866
#  I:30 Train-Err:0.364 Train-Acc:0.845 Test-Err:0.327 Test-Acc:0.861
#  I:31 Train-Err:0.353 Train-Acc:0.859 Test-Err:0.319 Test-Acc:0.857
#  I:32 Train-Err:0.356 Train-Acc:0.847 Test-Err:0.327 Test-Acc:0.857
#  I:33 Train-Err:0.331 Train-Acc:0.869 Test-Err:0.322 Test-Acc:0.851
#  I:34 Train-Err:0.364 Train-Acc:0.835 Test-Err:0.321 Test-Acc:0.866
#  I:35 Train-Err:0.365 Train-Acc:0.836 Test-Err:0.313 Test-Acc:0.862
#  I:36 Train-Err:0.351 Train-Acc:0.847 Test-Err:0.337 Test-Acc:0.865
#  I:37 Train-Err:0.355 Train-Acc:0.855 Test-Err:0.355 Test-Acc:0.861
#  I:38 Train-Err:0.367 Train-Acc:0.844 Test-Err:0.331 Test-Acc:0.854
#  I:39 Train-Err:0.343 Train-Acc:0.857 Test-Err:0.323 Test-Acc:0.861
#  I:40 Train-Err:0.345 Train-Acc:0.851 Test-Err:0.305 Test-Acc:0.870
#  I:41 Train-Err:0.344 Train-Acc:0.848 Test-Err:0.340 Test-Acc:0.838
#  I:42 Train-Err:0.354 Train-Acc:0.851 Test-Err:0.330 Test-Acc:0.850
#  I:43 Train-Err:0.342 Train-Acc:0.859 Test-Err:0.329 Test-Acc:0.867
#  I:44 Train-Err:0.351 Train-Acc:0.851 Test-Err:0.333 Test-Acc:0.846
#  I:45 Train-Err:0.327 Train-Acc:0.851 Test-Err:0.316 Test-Acc:0.854
#  I:46 Train-Err:0.326 Train-Acc:0.867 Test-Err:0.317 Test-Acc:0.863
#  I:47 Train-Err:0.328 Train-Acc:0.861 Test-Err:0.308 Test-Acc:0.864
#  I:48 Train-Err:0.316 Train-Acc:0.889 Test-Err:0.344 Test-Acc:0.849
#  I:49 Train-Err:0.322 Train-Acc:0.864 Test-Err:0.331 Test-Acc:0.853
#  I:50 Train-Err:0.317 Train-Acc:0.868 Test-Err:0.335 Test-Acc:0.841
#  I:51 Train-Err:0.332 Train-Acc:0.863 Test-Err:0.355 Test-Acc:0.851
#  I:52 Train-Err:0.358 Train-Acc:0.843 Test-Err:0.344 Test-Acc:0.853
#  I:53 Train-Err:0.339 Train-Acc:0.862 Test-Err:0.311 Test-Acc:0.859
#  I:54 Train-Err:0.318 Train-Acc:0.874 Test-Err:0.323 Test-Acc:0.843
#  I:55 Train-Err:0.337 Train-Acc:0.857 Test-Err:0.333 Test-Acc:0.852
#  I:56 Train-Err:0.317 Train-Acc:0.872 Test-Err:0.328 Test-Acc:0.860
#  I:57 Train-Err:0.338 Train-Acc:0.85 Test-Err:0.310 Test-Acc:0.861
#  I:58 Train-Err:0.332 Train-Acc:0.856 Test-Err:0.317 Test-Acc:0.844
#  I:59 Train-Err:0.337 Train-Acc:0.871 Test-Err:0.325 Test-Acc:0.853
#  I:60 Train-Err:0.336 Train-Acc:0.862 Test-Err:0.363 Test-Acc:0.839
#  I:61 Train-Err:0.317 Train-Acc:0.875 Test-Err:0.318 Test-Acc:0.862
#  I:62 Train-Err:0.322 Train-Acc:0.858 Test-Err:0.373 Test-Acc:0.837
#  I:63 Train-Err:0.335 Train-Acc:0.867 Test-Err:0.320 Test-Acc:0.853
#  I:64 Train-Err:0.326 Train-Acc:0.861 Test-Err:0.322 Test-Acc:0.861
#  I:65 Train-Err:0.330 Train-Acc:0.863 Test-Err:0.361 Test-Acc:0.832
#  I:66 Train-Err:0.318 Train-Acc:0.864 Test-Err:0.312 Test-Acc:0.847
#  I:67 Train-Err:0.313 Train-Acc:0.87 Test-Err:0.336 Test-Acc:0.848
#  I:68 Train-Err:0.345 Train-Acc:0.849 Test-Err:0.312 Test-Acc:0.853
#  I:69 Train-Err:0.304 Train-Acc:0.879 Test-Err:0.336 Test-Acc:0.850
#  I:70 Train-Err:0.332 Train-Acc:0.859 Test-Err:0.319 Test-Acc:0.853
#  I:71 Train-Err:0.300 Train-Acc:0.868 Test-Err:0.325 Test-Acc:0.857
#  I:72 Train-Err:0.326 Train-Acc:0.854 Test-Err:0.346 Test-Acc:0.853
#  I:73 Train-Err:0.312 Train-Acc:0.868 Test-Err:0.314 Test-Acc:0.854
#  I:74 Train-Err:0.313 Train-Acc:0.87 Test-Err:0.313 Test-Acc:0.854
#  I:75 Train-Err:0.304 Train-Acc:0.871 Test-Err:0.297 Test-Acc:0.860
#  I:76 Train-Err:0.300 Train-Acc:0.879 Test-Err:0.314 Test-Acc:0.860
#  I:77 Train-Err:0.318 Train-Acc:0.872 Test-Err:0.333 Test-Acc:0.845
#  I:78 Train-Err:0.300 Train-Acc:0.872 Test-Err:0.324 Test-Acc:0.856
#  I:79 Train-Err:0.314 Train-Acc:0.873 Test-Err:0.310 Test-Acc:0.862
#  I:80 Train-Err:0.305 Train-Acc:0.874 Test-Err:0.325 Test-Acc:0.856
#  I:81 Train-Err:0.331 Train-Acc:0.845 Test-Err:0.345 Test-Acc:0.848
#  I:82 Train-Err:0.332 Train-Acc:0.85 Test-Err:0.328 Test-Acc:0.845
#  I:83 Train-Err:0.302 Train-Acc:0.875 Test-Err:0.314 Test-Acc:0.861
#  I:84 Train-Err:0.306 Train-Acc:0.865 Test-Err:0.358 Test-Acc:0.851
#  I:85 Train-Err:0.298 Train-Acc:0.882 Test-Err:0.311 Test-Acc:0.855
#  I:86 Train-Err:0.314 Train-Acc:0.866 Test-Err:0.312 Test-Acc:0.858
#  I:87 Train-Err:0.332 Train-Acc:0.848 Test-Err:0.347 Test-Acc:0.846
#  I:88 Train-Err:0.318 Train-Acc:0.859 Test-Err:0.334 Test-Acc:0.851
#  I:89 Train-Err:0.310 Train-Acc:0.867 Test-Err:0.347 Test-Acc:0.841
#  I:90 Train-Err:0.312 Train-Acc:0.881 Test-Err:0.320 Test-Acc:0.856
#  I:91 Train-Err:0.298 Train-Acc:0.882 Test-Err:0.329 Test-Acc:0.849
#  I:92 Train-Err:0.314 Train-Acc:0.86 Test-Err:0.313 Test-Acc:0.854
#  I:93 Train-Err:0.304 Train-Acc:0.877 Test-Err:0.333 Test-Acc:0.833
#  I:94 Train-Err:0.296 Train-Acc:0.888 Test-Err:0.329 Test-Acc:0.852
#  I:95 Train-Err:0.302 Train-Acc:0.877 Test-Err:0.330 Test-Acc:0.860
#  I:96 Train-Err:0.294 Train-Acc:0.883 Test-Err:0.334 Test-Acc:0.845
#  I:97 Train-Err:0.325 Train-Acc:0.852 Test-Err:0.315 Test-Acc:0.857
#  I:98 Train-Err:0.311 Train-Acc:0.877 Test-Err:0.358 Test-Acc:0.845
#  I:99 Train-Err:0.307 Train-Acc:0.861 Test-Err:0.329 Test-Acc:0.857
#  I:100 Train-Err:0.313 Train-Acc:0.866 Test-Err:0.329 Test-Acc:0.840
#  I:101 Train-Err:0.320 Train-Acc:0.871 Test-Err:0.349 Test-Acc:0.832
#  I:102 Train-Err:0.323 Train-Acc:0.861 Test-Err:0.328 Test-Acc:0.854
#  I:103 Train-Err:0.306 Train-Acc:0.875 Test-Err:0.344 Test-Acc:0.848
#  I:104 Train-Err:0.303 Train-Acc:0.864 Test-Err:0.316 Test-Acc:0.851
#  I:105 Train-Err:0.300 Train-Acc:0.867 Test-Err:0.340 Test-Acc:0.856
#  I:106 Train-Err:0.298 Train-Acc:0.877 Test-Err:0.354 Test-Acc:0.850
#  I:107 Train-Err:0.296 Train-Acc:0.886 Test-Err:0.331 Test-Acc:0.846
#  I:108 Train-Err:0.304 Train-Acc:0.871 Test-Err:0.329 Test-Acc:0.847
#  I:109 Train-Err:0.302 Train-Acc:0.876 Test-Err:0.337 Test-Acc:0.852
#  I:110 Train-Err:0.289 Train-Acc:0.88 Test-Err:0.351 Test-Acc:0.835
#  I:111 Train-Err:0.297 Train-Acc:0.885 Test-Err:0.320 Test-Acc:0.856
#  I:112 Train-Err:0.290 Train-Acc:0.874 Test-Err:0.345 Test-Acc:0.852
#  I:113 Train-Err:0.301 Train-Acc:0.871 Test-Err:0.324 Test-Acc:0.851
#  I:114 Train-Err:0.305 Train-Acc:0.876 Test-Err:0.313 Test-Acc:0.854
#  I:115 Train-Err:0.298 Train-Acc:0.875 Test-Err:0.349 Test-Acc:0.847
#  I:116 Train-Err:0.283 Train-Acc:0.883 Test-Err:0.312 Test-Acc:0.857
#  I:117 Train-Err:0.316 Train-Acc:0.872 Test-Err:0.376 Test-Acc:0.823
#  I:118 Train-Err:0.304 Train-Acc:0.875 Test-Err:0.343 Test-Acc:0.838
#  I:119 Train-Err:0.295 Train-Acc:0.886 Test-Err:0.325 Test-Acc:0.855
#  I:120 Train-Err:0.293 Train-Acc:0.875 Test-Err:0.327 Test-Acc:0.849
#  I:121 Train-Err:0.304 Train-Acc:0.876 Test-Err:0.339 Test-Acc:0.845
#  I:122 Train-Err:0.286 Train-Acc:0.879 Test-Err:0.333 Test-Acc:0.838
#  I:123 Train-Err:0.289 Train-Acc:0.897 Test-Err:0.348 Test-Acc:0.849
#  I:124 Train-Err:0.296 Train-Acc:0.877 Test-Err:0.334 Test-Acc:0.848
#  I:125 Train-Err:0.295 Train-Acc:0.878 Test-Err:0.320 Test-Acc:0.852
#  I:126 Train-Err:0.287 Train-Acc:0.88 Test-Err:0.334 Test-Acc:0.844
#  I:127 Train-Err:0.290 Train-Acc:0.891 Test-Err:0.347 Test-Acc:0.839
#  I:128 Train-Err:0.289 Train-Acc:0.886 Test-Err:0.346 Test-Acc:0.843
#  I:129 Train-Err:0.291 Train-Acc:0.882 Test-Err:0.318 Test-Acc:0.854
#  I:130 Train-Err:0.310 Train-Acc:0.875 Test-Err:0.320 Test-Acc:0.853
#  I:131 Train-Err:0.296 Train-Acc:0.869 Test-Err:0.333 Test-Acc:0.844
#  I:132 Train-Err:0.291 Train-Acc:0.885 Test-Err:0.326 Test-Acc:0.853
#  I:133 Train-Err:0.268 Train-Acc:0.895 Test-Err:0.320 Test-Acc:0.846
#  I:134 Train-Err:0.293 Train-Acc:0.871 Test-Err:0.355 Test-Acc:0.827
#  I:135 Train-Err:0.298 Train-Acc:0.875 Test-Err:0.315 Test-Acc:0.853
#  I:136 Train-Err:0.287 Train-Acc:0.887 Test-Err:0.341 Test-Acc:0.845
#  I:137 Train-Err:0.295 Train-Acc:0.887 Test-Err:0.326 Test-Acc:0.843
#  I:138 Train-Err:0.301 Train-Acc:0.871 Test-Err:0.319 Test-Acc:0.840
#  I:139 Train-Err:0.301 Train-Acc:0.877 Test-Err:0.314 Test-Acc:0.855
#  I:140 Train-Err:0.283 Train-Acc:0.872 Test-Err:0.323 Test-Acc:0.844
#  I:141 Train-Err:0.293 Train-Acc:0.878 Test-Err:0.331 Test-Acc:0.850
#  I:142 Train-Err:0.295 Train-Acc:0.876 Test-Err:0.316 Test-Acc:0.852
#  I:143 Train-Err:0.304 Train-Acc:0.874 Test-Err:0.344 Test-Acc:0.844
#  I:144 Train-Err:0.293 Train-Acc:0.875 Test-Err:0.359 Test-Acc:0.833
#  I:145 Train-Err:0.270 Train-Acc:0.885 Test-Err:0.342 Test-Acc:0.842
#  I:146 Train-Err:0.291 Train-Acc:0.872 Test-Err:0.314 Test-Acc:0.851
#  I:147 Train-Err:0.294 Train-Acc:0.881 Test-Err:0.326 Test-Acc:0.849
#  I:148 Train-Err:0.278 Train-Acc:0.907 Test-Err:0.326 Test-Acc:0.844
#  I:149 Train-Err:0.287 Train-Acc:0.883 Test-Err:0.340 Test-Acc:0.835
#  I:150 Train-Err:0.298 Train-Acc:0.871 Test-Err:0.316 Test-Acc:0.852
#  I:151 Train-Err:0.306 Train-Acc:0.872 Test-Err:0.369 Test-Acc:0.828
#  I:152 Train-Err:0.292 Train-Acc:0.883 Test-Err:0.330 Test-Acc:0.841
#  I:153 Train-Err:0.277 Train-Acc:0.884 Test-Err:0.308 Test-Acc:0.850
#  I:154 Train-Err:0.284 Train-Acc:0.89 Test-Err:0.338 Test-Acc:0.85
#  I:155 Train-Err:0.287 Train-Acc:0.883 Test-Err:0.346 Test-Acc:0.840
#  I:156 Train-Err:0.288 Train-Acc:0.884 Test-Err:0.345 Test-Acc:0.833
#  I:157 Train-Err:0.298 Train-Acc:0.861 Test-Err:0.322 Test-Acc:0.848
#  I:158 Train-Err:0.309 Train-Acc:0.865 Test-Err:0.313 Test-Acc:0.848
#  I:159 Train-Err:0.304 Train-Acc:0.872 Test-Err:0.340 Test-Acc:0.848
#  I:160 Train-Err:0.312 Train-Acc:0.868 Test-Err:0.350 Test-Acc:0.854
#  I:161 Train-Err:0.287 Train-Acc:0.875 Test-Err:0.311 Test-Acc:0.854
#  I:162 Train-Err:0.276 Train-Acc:0.887 Test-Err:0.321 Test-Acc:0.845
#  I:163 Train-Err:0.298 Train-Acc:0.876 Test-Err:0.389 Test-Acc:0.792
#  I:164 Train-Err:0.286 Train-Acc:0.876 Test-Err:0.315 Test-Acc:0.850
#  I:165 Train-Err:0.285 Train-Acc:0.89 Test-Err:0.345 Test-Acc:0.837
#  I:166 Train-Err:0.293 Train-Acc:0.88 Test-Err:0.341 Test-Acc:0.843
#  I:167 Train-Err:0.288 Train-Acc:0.882 Test-Err:0.337 Test-Acc:0.839
#  I:168 Train-Err:0.283 Train-Acc:0.889 Test-Err:0.368 Test-Acc:0.836
#  I:169 Train-Err:0.290 Train-Acc:0.874 Test-Err:0.334 Test-Acc:0.850
#  I:170 Train-Err:0.293 Train-Acc:0.869 Test-Err:0.320 Test-Acc:0.851
#  I:171 Train-Err:0.279 Train-Acc:0.886 Test-Err:0.340 Test-Acc:0.844
#  I:172 Train-Err:0.276 Train-Acc:0.879 Test-Err:0.334 Test-Acc:0.841
#  I:173 Train-Err:0.296 Train-Acc:0.872 Test-Err:0.348 Test-Acc:0.845
#  I:174 Train-Err:0.283 Train-Acc:0.885 Test-Err:0.362 Test-Acc:0.834
#  I:175 Train-Err:0.300 Train-Acc:0.88 Test-Err:0.346 Test-Acc:0.83
#  I:176 Train-Err:0.294 Train-Acc:0.87 Test-Err:0.342 Test-Acc:0.837
#  I:177 Train-Err:0.278 Train-Acc:0.884 Test-Err:0.356 Test-Acc:0.835
#  I:178 Train-Err:0.282 Train-Acc:0.88 Test-Err:0.323 Test-Acc:0.848
#  I:179 Train-Err:0.279 Train-Acc:0.883 Test-Err:0.341 Test-Acc:0.850
#  I:180 Train-Err:0.302 Train-Acc:0.864 Test-Err:0.349 Test-Acc:0.837
#  I:181 Train-Err:0.278 Train-Acc:0.888 Test-Err:0.327 Test-Acc:0.845
#  I:182 Train-Err:0.286 Train-Acc:0.886 Test-Err:0.321 Test-Acc:0.850
#  I:183 Train-Err:0.273 Train-Acc:0.886 Test-Err:0.334 Test-Acc:0.834
#  I:184 Train-Err:0.277 Train-Acc:0.887 Test-Err:0.335 Test-Acc:0.843
#  I:185 Train-Err:0.278 Train-Acc:0.884 Test-Err:0.335 Test-Acc:0.838
#  I:186 Train-Err:0.276 Train-Acc:0.884 Test-Err:0.335 Test-Acc:0.847
#  I:187 Train-Err:0.269 Train-Acc:0.893 Test-Err:0.317 Test-Acc:0.851
#  I:188 Train-Err:0.291 Train-Acc:0.876 Test-Err:0.313 Test-Acc:0.847
#  I:189 Train-Err:0.280 Train-Acc:0.892 Test-Err:0.325 Test-Acc:0.848
#  I:190 Train-Err:0.274 Train-Acc:0.882 Test-Err:0.357 Test-Acc:0.830
#  I:191 Train-Err:0.284 Train-Acc:0.884 Test-Err:0.334 Test-Acc:0.840
#  I:192 Train-Err:0.304 Train-Acc:0.858 Test-Err:0.348 Test-Acc:0.821
#  I:193 Train-Err:0.302 Train-Acc:0.875 Test-Err:0.320 Test-Acc:0.856
#  I:194 Train-Err:0.300 Train-Acc:0.86 Test-Err:0.346 Test-Acc:0.848
#  I:195 Train-Err:0.259 Train-Acc:0.9 Test-Err:0.334 Test-Acc:0.840
#  I:196 Train-Err:0.291 Train-Acc:0.875 Test-Err:0.316 Test-Acc:0.851
#  I:197 Train-Err:0.303 Train-Acc:0.855 Test-Err:0.325 Test-Acc:0.85
#  I:198 Train-Err:0.286 Train-Acc:0.875 Test-Err:0.335 Test-Acc:0.846
#  I:199 Train-Err:0.270 Train-Acc:0.89 Test-Err:0.337 Test-Acc:0.849
#  I:200 Train-Err:0.284 Train-Acc:0.878 Test-Err:0.362 Test-Acc:0.806
#  I:201 Train-Err:0.275 Train-Acc:0.876 Test-Err:0.333 Test-Acc:0.848
#  I:202 Train-Err:0.291 Train-Acc:0.863 Test-Err:0.339 Test-Acc:0.847
#  I:203 Train-Err:0.289 Train-Acc:0.886 Test-Err:0.366 Test-Acc:0.849
#  I:204 Train-Err:0.282 Train-Acc:0.884 Test-Err:0.330 Test-Acc:0.842
#  I:205 Train-Err:0.288 Train-Acc:0.884 Test-Err:0.335 Test-Acc:0.849
#  I:206 Train-Err:0.283 Train-Acc:0.876 Test-Err:0.349 Test-Acc:0.842
#  I:207 Train-Err:0.264 Train-Acc:0.895 Test-Err:0.325 Test-Acc:0.841
#  I:208 Train-Err:0.288 Train-Acc:0.878 Test-Err:0.350 Test-Acc:0.833
#  I:209 Train-Err:0.287 Train-Acc:0.875 Test-Err:0.316 Test-Acc:0.848
#  I:210 Train-Err:0.279 Train-Acc:0.896 Test-Err:0.342 Test-Acc:0.848
#  I:211 Train-Err:0.293 Train-Acc:0.875 Test-Err:0.338 Test-Acc:0.836
#  I:212 Train-Err:0.278 Train-Acc:0.887 Test-Err:0.323 Test-Acc:0.841
#  I:213 Train-Err:0.281 Train-Acc:0.879 Test-Err:0.344 Test-Acc:0.838
#  I:214 Train-Err:0.276 Train-Acc:0.883 Test-Err:0.327 Test-Acc:0.852
#  I:215 Train-Err:0.267 Train-Acc:0.891 Test-Err:0.357 Test-Acc:0.827
#  I:216 Train-Err:0.263 Train-Acc:0.899 Test-Err:0.331 Test-Acc:0.841
#  I:217 Train-Err:0.280 Train-Acc:0.89 Test-Err:0.338 Test-Acc:0.839
#  I:218 Train-Err:0.307 Train-Acc:0.853 Test-Err:0.332 Test-Acc:0.846
#  I:219 Train-Err:0.303 Train-Acc:0.865 Test-Err:0.337 Test-Acc:0.844
#  I:220 Train-Err:0.283 Train-Acc:0.877 Test-Err:0.329 Test-Acc:0.849
#  I:221 Train-Err:0.280 Train-Acc:0.883 Test-Err:0.328 Test-Acc:0.845
#  I:222 Train-Err:0.273 Train-Acc:0.893 Test-Err:0.342 Test-Acc:0.838
#  I:223 Train-Err:0.289 Train-Acc:0.867 Test-Err:0.325 Test-Acc:0.839
#  I:224 Train-Err:0.281 Train-Acc:0.888 Test-Err:0.336 Test-Acc:0.85
#  I:225 Train-Err:0.279 Train-Acc:0.884 Test-Err:0.340 Test-Acc:0.845
#  I:226 Train-Err:0.292 Train-Acc:0.862 Test-Err:0.342 Test-Acc:0.838
#  I:227 Train-Err:0.272 Train-Acc:0.881 Test-Err:0.338 Test-Acc:0.846
#  I:228 Train-Err:0.283 Train-Acc:0.88 Test-Err:0.326 Test-Acc:0.848
#  I:229 Train-Err:0.266 Train-Acc:0.9 Test-Err:0.330 Test-Acc:0.845
#  I:230 Train-Err:0.284 Train-Acc:0.88 Test-Err:0.351 Test-Acc:0.843
#  I:231 Train-Err:0.270 Train-Acc:0.9 Test-Err:0.341 Test-Acc:0.839
#  I:232 Train-Err:0.280 Train-Acc:0.875 Test-Err:0.337 Test-Acc:0.848
#  I:233 Train-Err:0.260 Train-Acc:0.903 Test-Err:0.328 Test-Acc:0.848
#  I:234 Train-Err:0.295 Train-Acc:0.871 Test-Err:0.332 Test-Acc:0.847
#  I:235 Train-Err:0.264 Train-Acc:0.892 Test-Err:0.331 Test-Acc:0.844
#  I:236 Train-Err:0.254 Train-Acc:0.897 Test-Err:0.328 Test-Acc:0.844
#  I:237 Train-Err:0.275 Train-Acc:0.886 Test-Err:0.352 Test-Acc:0.849
#  I:238 Train-Err:0.284 Train-Acc:0.879 Test-Err:0.335 Test-Acc:0.851
#  I:239 Train-Err:0.278 Train-Acc:0.884 Test-Err:0.341 Test-Acc:0.842
#  I:240 Train-Err:0.281 Train-Acc:0.884 Test-Err:0.325 Test-Acc:0.843
#  I:241 Train-Err:0.268 Train-Acc:0.889 Test-Err:0.337 Test-Acc:0.838
#  I:242 Train-Err:0.272 Train-Acc:0.888 Test-Err:0.344 Test-Acc:0.841
#  I:243 Train-Err:0.283 Train-Acc:0.869 Test-Err:0.334 Test-Acc:0.842
#  I:244 Train-Err:0.298 Train-Acc:0.861 Test-Err:0.334 Test-Acc:0.844
#  I:245 Train-Err:0.264 Train-Acc:0.895 Test-Err:0.333 Test-Acc:0.846
#  I:246 Train-Err:0.274 Train-Acc:0.877 Test-Err:0.356 Test-Acc:0.839
#  I:247 Train-Err:0.265 Train-Acc:0.887 Test-Err:0.350 Test-Acc:0.830
#  I:248 Train-Err:0.270 Train-Acc:0.888 Test-Err:0.332 Test-Acc:0.842
#  I:249 Train-Err:0.272 Train-Acc:0.88 Test-Err:0.340 Test-Acc:0.846
#  I:250 Train-Err:0.277 Train-Acc:0.879 Test-Err:0.327 Test-Acc:0.844
#  I:251 Train-Err:0.274 Train-Acc:0.883 Test-Err:0.333 Test-Acc:0.843
#  I:252 Train-Err:0.294 Train-Acc:0.871 Test-Err:0.362 Test-Acc:0.822
#  I:253 Train-Err:0.277 Train-Acc:0.887 Test-Err:0.353 Test-Acc:0.832
#  I:254 Train-Err:0.274 Train-Acc:0.884 Test-Err:0.329 Test-Acc:0.849
#  I:255 Train-Err:0.271 Train-Acc:0.885 Test-Err:0.323 Test-Acc:0.847
#  I:256 Train-Err:0.278 Train-Acc:0.892 Test-Err:0.339 Test-Acc:0.838
#  I:257 Train-Err:0.283 Train-Acc:0.87 Test-Err:0.325 Test-Acc:0.847
#  I:258 Train-Err:0.271 Train-Acc:0.89 Test-Err:0.333 Test-Acc:0.837
#  I:259 Train-Err:0.274 Train-Acc:0.898 Test-Err:0.349 Test-Acc:0.836
#  I:260 Train-Err:0.264 Train-Acc:0.896 Test-Err:0.321 Test-Acc:0.841
#  I:261 Train-Err:0.297 Train-Acc:0.863 Test-Err:0.330 Test-Acc:0.835
#  I:262 Train-Err:0.281 Train-Acc:0.884 Test-Err:0.336 Test-Acc:0.843
#  I:263 Train-Err:0.290 Train-Acc:0.863 Test-Err:0.330 Test-Acc:0.840
#  I:264 Train-Err:0.275 Train-Acc:0.88 Test-Err:0.332 Test-Acc:0.842
#  I:265 Train-Err:0.266 Train-Acc:0.893 Test-Err:0.324 Test-Acc:0.844
#  I:266 Train-Err:0.281 Train-Acc:0.873 Test-Err:0.335 Test-Acc:0.848
#  I:267 Train-Err:0.281 Train-Acc:0.889 Test-Err:0.358 Test-Acc:0.830
#  I:268 Train-Err:0.259 Train-Acc:0.901 Test-Err:0.336 Test-Acc:0.842
#  I:269 Train-Err:0.275 Train-Acc:0.88 Test-Err:0.351 Test-Acc:0.842
#  I:270 Train-Err:0.299 Train-Acc:0.865 Test-Err:0.323 Test-Acc:0.844
#  I:271 Train-Err:0.277 Train-Acc:0.883 Test-Err:0.342 Test-Acc:0.836
#  I:272 Train-Err:0.275 Train-Acc:0.874 Test-Err:0.371 Test-Acc:0.831
#  I:273 Train-Err:0.276 Train-Acc:0.888 Test-Err:0.334 Test-Acc:0.838
#  I:274 Train-Err:0.276 Train-Acc:0.872 Test-Err:0.346 Test-Acc:0.846
#  I:275 Train-Err:0.263 Train-Acc:0.881 Test-Err:0.324 Test-Acc:0.847
#  I:276 Train-Err:0.278 Train-Acc:0.883 Test-Err:0.334 Test-Acc:0.845
#  I:277 Train-Err:0.284 Train-Acc:0.876 Test-Err:0.342 Test-Acc:0.842
#  I:278 Train-Err:0.238 Train-Acc:0.908 Test-Err:0.342 Test-Acc:0.835
#  I:279 Train-Err:0.272 Train-Acc:0.893 Test-Err:0.332 Test-Acc:0.840
#  I:280 Train-Err:0.273 Train-Acc:0.889 Test-Err:0.324 Test-Acc:0.844
#  I:281 Train-Err:0.270 Train-Acc:0.891 Test-Err:0.326 Test-Acc:0.842
#  I:282 Train-Err:0.261 Train-Acc:0.889 Test-Err:0.345 Test-Acc:0.832
#  I:283 Train-Err:0.271 Train-Acc:0.884 Test-Err:0.341 Test-Acc:0.841
#  I:284 Train-Err:0.279 Train-Acc:0.883 Test-Err:0.344 Test-Acc:0.842
#  I:285 Train-Err:0.256 Train-Acc:0.894 Test-Err:0.346 Test-Acc:0.836
#  I:286 Train-Err:0.269 Train-Acc:0.889 Test-Err:0.345 Test-Acc:0.840
#  I:287 Train-Err:0.274 Train-Acc:0.872 Test-Err:0.332 Test-Acc:0.846
#  I:288 Train-Err:0.272 Train-Acc:0.885 Test-Err:0.340 Test-Acc:0.828
#  I:289 Train-Err:0.276 Train-Acc:0.892 Test-Err:0.354 Test-Acc:0.834
#  I:290 Train-Err:0.263 Train-Acc:0.887 Test-Err:0.336 Test-Acc:0.836
#  I:291 Train-Err:0.270 Train-Acc:0.883 Test-Err:0.323 Test-Acc:0.848
#  I:292 Train-Err:0.266 Train-Acc:0.899 Test-Err:0.345 Test-Acc:0.843
#  I:293 Train-Err:0.266 Train-Acc:0.889 Test-Err:0.337 Test-Acc:0.836
#  I:294 Train-Err:0.266 Train-Acc:0.895 Test-Err:0.365 Test-Acc:0.833
#  I:295 Train-Err:0.264 Train-Acc:0.891 Test-Err:0.334 Test-Acc:0.843
#  I:296 Train-Err:0.267 Train-Acc:0.895 Test-Err:0.342 Test-Acc:0.841
#  I:297 Train-Err:0.275 Train-Acc:0.878 Test-Err:0.328 Test-Acc:0.843
#  I:298 Train-Err:0.290 Train-Acc:0.874 Test-Err:0.323 Test-Acc:0.844
#  I:299 Train-Err:0.266 Train-Acc:0.887 Test-Err:0.332 Test-Acc:0.843
