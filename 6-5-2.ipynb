# %%
# !pip install numpy

# %%
import numpy as np

a = np.array([0, 1, 2, 1])
b = np.array([2, 2, 2, 3])

print("a + b = " + str(a + b))
print("a * b = " + str(a * b))
print("a dot b = " + str(a.dot(b)))
# Out:
# a + b = [2 3 4 4]
# a * b = [0 2 4 3]
# a dot b = 9
