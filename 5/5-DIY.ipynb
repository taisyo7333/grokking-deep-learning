# %% [markdown]
# # DIY

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (2.5.1)

# %%
import numpy as np

# %%
# input
toes = np.array([8.5, 9.5, 9.9, 9.0])
wlrec = np.array([0.65, 0.8, 0.8, 0.9])
nfans = np.array([1.2, 1.3, 0.5, 1.0])

input = np.array([toes[0], wlrec[0], nfans[0]])

# goal_predctiona
win_or_lose_binary = [1, 1, 0, 1]
goal_pred = win_or_lose_binary[0]

# weights
weights = [0.1, 0.2, -0.1]
alpha = 0.01

for iteration in range(3):

    # prediction
    pred = np.dot(input, weights)
    print("input:", input)
    print("weights:", weights)
    print("pred:", pred)
    # error
    error = (goal_pred - pred) ** 2
    print("error:", error)
    # delta
    delta = (pred - goal_pred)
    print("delta:", delta)
    # derivative
    derivative = input * delta
    print("derivative:", derivative)
    # update weights
    weights = weights - alpha * derivative
    print("weights:", weights)
# Out:
# input: [8.5  0.65 1.2 ]
# weights: [0.1, 0.2, -0.1]
# pred: 0.8600000000000001
# error: 0.01959999999999997
# delta: -0.1399999999999999
# derivative: [-1.19  -0.091 -0.168]
# weights: [ 0.1119   0.20091 -0.09832]
# input: [8.5  0.65 1.2 ]
# weights: [ 0.1119   0.20091 -0.09832]
# pred: 0.9637574999999999
# error: 0.0013135188062500048
# delta: -0.036242500000000066
# derivative: [-0.30806125 -0.02355763 -0.043491  ]
# weights: [ 0.11498061  0.20114558 -0.09788509]
# input: [8.5  0.65 1.2 ]
# weights: [ 0.11498061  0.20114558 -0.09788509]
# pred: 0.9906177228125002
# error: 8.802712522307997e-05
# delta: -0.009382277187499843
# derivative: [-0.07974936 -0.00609848 -0.01125873]
# weights: [ 0.11577811  0.20120656 -0.0977725 ]
