# %%
# !pip install numpy

# %%
import numpy as np

# %%
output = np.dot(3, [1, 2, 3])
print(output)
np.dot([1, 2, 3], 3)
print(output)

output = np.dot([1, 2, 3], [4, 5, 6])
print(output)

# np.array([1]).dot(np.array([4, 5, 6]))
# Out:
# [3 6 9]
# [3 6 9]
# 32
