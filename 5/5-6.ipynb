# %% [markdown]
# # 複数の入力と出力を持つ勾配降下法
# https://github.com/iamtrask/Grokking-Deep-Learning/blob/master/Chapter5%20-%20Generalizing%20Gradient%20Descent%20-%20Learning%20Multiple%20Weights%20at%20a%20Time.ipynb

# %%
weights = [
    # toes,wlrec,nfans
    [0.1, 0.1, -0.3], # hurt?
    [0.1, 0.2, 0.0],  # win?
    [0.0, 1.3, 0.1]   # sad?
]

def w_sum(a, b):
    assert(len(a) == len(b))
    output = 0

    for i in range(len(a)):
        output += (a[i] * b[i])
    return output

def vect_mat_mul(vect, matrix):
    assert(len(vect) == len(matrix))
    output = [0,0,0]
    for i in range(len(vect)):
        output[i] = w_sum(vect, matrix[i])
    return output

def neural_network(input, weights):
    pred = vect_mat_mul(input, weights)
    return pred

# Input data
toes = [8.5, 9.5, 9.9, 9.0]
wlrec = [0.65, 0.8, 0.8, 0.9]
nfans = [1.2, 1.3, 0.5, 1.0]
# goal predictions
hurt = [0.1, 0.0, 0.0, 0.1]
win = [1, 1, 0, 1]
sad = [0.1, 0.0, 0.1, 0.2]

alpha = 0.01

input = [toes[0], wlrec[0], nfans[0]]
truth = [hurt[0], win[0], sad[0]]

pred = neural_network(input, weights)

error = [0,0,0]
delta = [0,0,0]

for i in range(len(truth)):
    error[i] = (pred[i] - truth[i]) ** 2
    delta[i] = pred[i] - truth[i]

# %%
# !pip install numpy
import numpy as np

def outer_prod(a, b):
    # just a matrix of zeros
    out = np.zeros((len(a), len(b)))

    for i in range(len(a)):
        for j in range(len(b)):
            out[i][j] = a[i] * b[j]
    return out

weights_delta = outer_prod(input, delta)
print(weights_delta)

for i in range(len(weights)):
    for j in range(len(weights[i])):
        weights[i][j] -= alpha * weights_delta[i][j]

print(weights)
# Out:
# Requirement already satisfied: numpy in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (2.5.1)
# [[ 3.8675  -0.17     7.3525 ]
#  [ 0.29575 -0.013    0.56225]
#  [ 0.546   -0.024    1.038  ]]
# [[np.float64(0.02264999999999999), np.float64(0.10339999999999999), np.float64(-0.44705)], [np.float64(0.094085), np.float64(0.20026), np.float64(-0.011245000000000003)], [np.float64(-0.010920000000000001), np.float64(1.30048), np.float64(0.07924)]]
