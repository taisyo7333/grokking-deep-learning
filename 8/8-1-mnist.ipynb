# %%
# !pip install --upgrade pip
# !pip install numpy
# !pip install tensorflow keras
# Out:
# Requirement already satisfied: pip in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (26.1.2)
# Requirement already satisfied: numpy in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (2.5.1)
# Requirement already satisfied: tensorflow in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (2.21.0)
# Requirement already satisfied: keras in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (3.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (26.2)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (7.35.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (2.34.2)
# Requirement already satisfied: setuptools in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (83.0.0)
# Requirement already satisfied: six>=1.12.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (4.16.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (1.82.1)
# Requirement already satisfied: numpy>=1.26.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (2.5.1)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (2026.6.17)
# Requirement already satisfied: rich in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from keras) (15.0.0)
# Requirement already satisfied: namex in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from keras) (0.1.0)
# Requirement already satisfied: optree in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from keras) (0.19.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from rich->keras) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from rich->keras) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
import sys, numpy as np
from keras.datasets import mnist
import matplotlib.pyplot as plt

(x_train, y_train), (x_test, y_test) = mnist.load_data()
# 255 is the maximum value of a pixel in an image. Dividing by 255 normalizes the pixel values to be between 0 and 1.
# each deata point is an pixel that has a value between 0 and 255, where 0 is black and 255 is white. By dividing by 255, we scale the pixel values to be between 0 and 1, which is a common practice in machine learning to improve convergence during training.
images, labels = (x_train[0:1000].reshape(1000, 28 * 28) / 255,
                  y_train[0:1000])
print(f"type(images)={type(images)}, type(labels)={type(labels)}")
print(f"images.shape={images.shape}, labels.shape={labels.shape}")

# 0,1,2,3,..,9
# 1000x10 matrix
one_hot_labels = np.zeros((len(labels), 10))
for i, label in enumerate(labels):
    one_hot_labels[i][label] = 1

# Goal Prediction: 0,1,2,3,..,9
labels = one_hot_labels

test_images = x_test.reshape(len(x_test), 28 * 28) / 255
test_labels = np.zeros((len(y_test), 10))
for i, label in enumerate(y_test):
    test_labels[i][label] = 1


def relu(x):
    return (x > 0) * x

def relu2derive(output):
    return output > 0

np.random.seed(1)

alpha, iterations, hidden_size = (0.005, 300, 40)
# 28x28 = 784
pixels_per_image, num_labels = (784, 10)

# -0.1 to 0.1
# 784x40 matrix
weights_0_1 = 0.2 * np.random.random((pixels_per_image, hidden_size)) - 0.1
# 40x10 matrix
weights_1_2 = 0.2 * np.random.random((hidden_size , num_labels)) - 0.1

print(f"weights_0_1.shape={weights_0_1.shape}, weights_1_2.shape={weights_1_2.shape}")
# print(f"weights_0_1=\n{weights_0_1}\nweights_1_2=\n{weights_1_2}")

# matlab
train_error = []
train_accuracy = []
test_error = []
test_accuracy = []

for j in range(iterations):
    train_err, train_acc = (0.0, 0)

    for i in range(len(images)):
        # input layer is 1x784
        layer_0 = images[i:i+1]
        # hidden layer is 1x40
        ## 1x784 * 783x40 = 1x40
        layer_1 = relu(np.dot(layer_0, weights_0_1))
        # prediction layer is 1x10
        # 1x40 * 40x10 = 1x10
        layer_2 = np.dot(layer_1, weights_1_2)

        goal_prediction = labels[i:i+1]

        train_err += np.sum((layer_2 - goal_prediction) ** 2)
        # argmax returns the index of the maximum value in an array.
        # In this case, it is used to determine the predicted class (the index of the highest value in layer_2) and compare it to the actual class (the index of the highest value in goal_prediction).
        # If they match, it means the prediction was correct, and we increment train_acc by 1.
        train_acc += int(np.argmax(layer_2) == np.argmax(goal_prediction))

        layer_2_delta = layer_2 - goal_prediction
        layer_1_delta = layer_2_delta.dot(weights_1_2.T) * relu2derive(layer_1)

        weights_1_2 = weights_1_2 - alpha * layer_1.T.dot(layer_2_delta)
        weights_0_1 = weights_0_1 - alpha * layer_0.T.dot(layer_1_delta)

    # str()[0:5] is used to limit the number of characters displayed for the training error, making the output more concise and easier to read. It effectively truncates the string representation of the training error to the first 5 characters, which typically includes the most significant digits.
    # print("Train-Err=" + str(train_err / float(len(images)))[0:5])
    #train_error.append(train_err / float(len(images)))
    #train_accuracy.append(train_acc / float(len(images)))

    sys.stdout.write(
        " I:" + str(j) + \
        " Train-Err:" + str(train_err / float(len(images)))[0:5] + \
        " Train-Acc:" + str(train_acc / float(len(images)))
    )

#    if( j % 10 == 0 or j == iterations - 1):
    test_err, test_acc = (0.0, 0)

    for i in range(len(test_images)):
        layer_0 = test_images[i:i+1]
        layer_1 = relu(np.dot(layer_0, weights_0_1))
        layer_2 = np.dot(layer_1, weights_1_2)

        test_err += np.sum((layer_2 - test_labels[i:i+1]) ** 2)
        test_acc += int(np.argmax(layer_2) == np.argmax(test_labels[i:i+1]))

    sys.stdout.write(
        " Test-Err:" + str(test_err / float(len(test_images)))[0:5] + \
        " Test-Acc:" + str(test_acc / float(len(test_images)))
    )
    sys.stdout.write("\n")

    # matplotlib
    train_error.append(train_err / float(len(images)))
    train_accuracy.append(train_acc / float(len(images)))
    test_error.append(test_err / float(len(test_images)))
    test_accuracy.append(test_acc / float(len(test_images)))

plt.figure(figsize=(8, 4))
plt.plot(train_error, label="Train-Err")
plt.plot(train_accuracy, label="Train-Acc")
plt.plot(test_error, label="Test-Err")
plt.plot(test_accuracy, label="Test-Acc")
plt.xlabel("Iterations")
plt.ylabel("Value")
plt.title("Training History over Iterations")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# type(images)=<class 'numpy.ndarray'>, type(labels)=<class 'numpy.ndarray'>
# images.shape=(1000, 784), labels.shape=(1000,)
# weights_0_1.shape=(784, 40), weights_1_2.shape=(40, 10)
#  I:0 Train-Err:0.729 Train-Acc:0.527 Test-Err:0.593 Test-Acc:0.6493
#  I:1 Train-Err:0.495 Train-Acc:0.749 Test-Err:0.510 Test-Acc:0.7184
#  I:2 Train-Err:0.416 Train-Acc:0.802 Test-Err:0.460 Test-Acc:0.767
#  I:3 Train-Err:0.362 Train-Acc:0.851 Test-Err:0.421 Test-Acc:0.8018
#  I:4 Train-Err:0.321 Train-Acc:0.883 Test-Err:0.393 Test-Acc:0.8212
#  I:5 Train-Err:0.289 Train-Acc:0.898 Test-Err:0.372 Test-Acc:0.8312
#  I:6 Train-Err:0.263 Train-Acc:0.908 Test-Err:0.356 Test-Acc:0.8384
#  I:7 Train-Err:0.242 Train-Acc:0.917 Test-Err:0.344 Test-Acc:0.8458
#  I:8 Train-Err:0.224 Train-Acc:0.923 Test-Err:0.334 Test-Acc:0.8505
#  I:9 Train-Err:0.210 Train-Acc:0.929 Test-Err:0.327 Test-Acc:0.8538
#  I:10 Train-Err:0.198 Train-Acc:0.94 Test-Err:0.321 Test-Acc:0.8559
#  I:11 Train-Err:0.187 Train-Acc:0.944 Test-Err:0.315 Test-Acc:0.8558
#  I:12 Train-Err:0.177 Train-Acc:0.952 Test-Err:0.311 Test-Acc:0.8581
#  I:13 Train-Err:0.168 Train-Acc:0.957 Test-Err:0.307 Test-Acc:0.8601
#  I:14 Train-Err:0.160 Train-Acc:0.957 Test-Err:0.304 Test-Acc:0.8615
#  I:15 Train-Err:0.153 Train-Acc:0.959 Test-Err:0.301 Test-Acc:0.8623
#  I:16 Train-Err:0.147 Train-Acc:0.96 Test-Err:0.298 Test-Acc:0.8638
#  I:17 Train-Err:0.141 Train-Acc:0.963 Test-Err:0.297 Test-Acc:0.8642
#  I:18 Train-Err:0.135 Train-Acc:0.964 Test-Err:0.295 Test-Acc:0.8635
#  I:19 Train-Err:0.130 Train-Acc:0.967 Test-Err:0.294 Test-Acc:0.8641
#  I:20 Train-Err:0.126 Train-Acc:0.972 Test-Err:0.293 Test-Acc:0.8638
#  I:21 Train-Err:0.121 Train-Acc:0.977 Test-Err:0.292 Test-Acc:0.864
#  I:22 Train-Err:0.117 Train-Acc:0.978 Test-Err:0.291 Test-Acc:0.8634
#  I:23 Train-Err:0.113 Train-Acc:0.98 Test-Err:0.291 Test-Acc:0.8643
#  I:24 Train-Err:0.110 Train-Acc:0.98 Test-Err:0.291 Test-Acc:0.8638
#  I:25 Train-Err:0.106 Train-Acc:0.981 Test-Err:0.290 Test-Acc:0.8637
#  I:26 Train-Err:0.103 Train-Acc:0.984 Test-Err:0.290 Test-Acc:0.8621
#  I:27 Train-Err:0.100 Train-Acc:0.988 Test-Err:0.290 Test-Acc:0.8614
#  I:28 Train-Err:0.097 Train-Acc:0.988 Test-Err:0.291 Test-Acc:0.8616
#  I:29 Train-Err:0.094 Train-Acc:0.989 Test-Err:0.291 Test-Acc:0.862
#  I:30 Train-Err:0.091 Train-Acc:0.991 Test-Err:0.291 Test-Acc:0.8614
#  I:31 Train-Err:0.089 Train-Acc:0.994 Test-Err:0.291 Test-Acc:0.8607
#  I:32 Train-Err:0.087 Train-Acc:0.994 Test-Err:0.292 Test-Acc:0.8608
#  I:33 Train-Err:0.084 Train-Acc:0.994 Test-Err:0.292 Test-Acc:0.8613
#  I:34 Train-Err:0.082 Train-Acc:0.994 Test-Err:0.292 Test-Acc:0.8616
#  I:35 Train-Err:0.080 Train-Acc:0.994 Test-Err:0.293 Test-Acc:0.8613
#  I:36 Train-Err:0.078 Train-Acc:0.994 Test-Err:0.293 Test-Acc:0.8613
#  I:37 Train-Err:0.076 Train-Acc:0.994 Test-Err:0.293 Test-Acc:0.8614
#  I:38 Train-Err:0.074 Train-Acc:0.994 Test-Err:0.294 Test-Acc:0.8608
#  I:39 Train-Err:0.073 Train-Acc:0.994 Test-Err:0.295 Test-Acc:0.8609
#  I:40 Train-Err:0.071 Train-Acc:0.994 Test-Err:0.295 Test-Acc:0.86
#  I:41 Train-Err:0.069 Train-Acc:0.994 Test-Err:0.296 Test-Acc:0.8601
#  I:42 Train-Err:0.068 Train-Acc:0.994 Test-Err:0.296 Test-Acc:0.8604
#  I:43 Train-Err:0.066 Train-Acc:0.994 Test-Err:0.297 Test-Acc:0.8598
#  I:44 Train-Err:0.065 Train-Acc:0.996 Test-Err:0.297 Test-Acc:0.8591
#  I:45 Train-Err:0.064 Train-Acc:0.996 Test-Err:0.298 Test-Acc:0.8595
#  I:46 Train-Err:0.062 Train-Acc:0.996 Test-Err:0.298 Test-Acc:0.8592
#  I:47 Train-Err:0.061 Train-Acc:0.996 Test-Err:0.298 Test-Acc:0.8585
#  I:48 Train-Err:0.060 Train-Acc:0.996 Test-Err:0.298 Test-Acc:0.8588
#  I:49 Train-Err:0.058 Train-Acc:0.995 Test-Err:0.299 Test-Acc:0.8584
#  I:50 Train-Err:0.057 Train-Acc:0.995 Test-Err:0.299 Test-Acc:0.8584
#  I:51 Train-Err:0.056 Train-Acc:0.995 Test-Err:0.300 Test-Acc:0.8578
#  I:52 Train-Err:0.055 Train-Acc:0.995 Test-Err:0.300 Test-Acc:0.8581
#  I:53 Train-Err:0.054 Train-Acc:0.995 Test-Err:0.301 Test-Acc:0.8573
#  I:54 Train-Err:0.053 Train-Acc:0.995 Test-Err:0.301 Test-Acc:0.8571
#  I:55 Train-Err:0.052 Train-Acc:0.995 Test-Err:0.301 Test-Acc:0.8577
#  I:56 Train-Err:0.051 Train-Acc:0.997 Test-Err:0.302 Test-Acc:0.8576
#  I:57 Train-Err:0.050 Train-Acc:0.997 Test-Err:0.302 Test-Acc:0.8576
#  I:58 Train-Err:0.049 Train-Acc:0.997 Test-Err:0.303 Test-Acc:0.8578
#  I:59 Train-Err:0.048 Train-Acc:0.997 Test-Err:0.303 Test-Acc:0.8575
#  I:60 Train-Err:0.047 Train-Acc:0.997 Test-Err:0.304 Test-Acc:0.8571
#  I:61 Train-Err:0.046 Train-Acc:0.997 Test-Err:0.304 Test-Acc:0.8568
#  I:62 Train-Err:0.046 Train-Acc:0.997 Test-Err:0.304 Test-Acc:0.8571
#  I:63 Train-Err:0.045 Train-Acc:0.997 Test-Err:0.305 Test-Acc:0.8576
#  I:64 Train-Err:0.044 Train-Acc:0.997 Test-Err:0.305 Test-Acc:0.8569
#  I:65 Train-Err:0.043 Train-Acc:0.997 Test-Err:0.306 Test-Acc:0.856
#  I:66 Train-Err:0.043 Train-Acc:0.997 Test-Err:0.306 Test-Acc:0.8559
#  I:67 Train-Err:0.042 Train-Acc:0.997 Test-Err:0.306 Test-Acc:0.8556
#  I:68 Train-Err:0.041 Train-Acc:0.998 Test-Err:0.307 Test-Acc:0.8557
#  I:69 Train-Err:0.041 Train-Acc:0.997 Test-Err:0.307 Test-Acc:0.8554
#  I:70 Train-Err:0.040 Train-Acc:0.998 Test-Err:0.307 Test-Acc:0.8555
#  I:71 Train-Err:0.039 Train-Acc:0.998 Test-Err:0.308 Test-Acc:0.8544
#  I:72 Train-Err:0.039 Train-Acc:0.998 Test-Err:0.308 Test-Acc:0.8553
#  I:73 Train-Err:0.038 Train-Acc:0.998 Test-Err:0.308 Test-Acc:0.8548
#  I:74 Train-Err:0.037 Train-Acc:0.998 Test-Err:0.309 Test-Acc:0.8538
#  I:75 Train-Err:0.037 Train-Acc:0.998 Test-Err:0.309 Test-Acc:0.8541
#  I:76 Train-Err:0.036 Train-Acc:0.998 Test-Err:0.309 Test-Acc:0.854
#  I:77 Train-Err:0.036 Train-Acc:0.998 Test-Err:0.310 Test-Acc:0.8531
#  I:78 Train-Err:0.035 Train-Acc:0.998 Test-Err:0.310 Test-Acc:0.8531
#  I:79 Train-Err:0.035 Train-Acc:0.998 Test-Err:0.310 Test-Acc:0.8535
#  I:80 Train-Err:0.034 Train-Acc:0.998 Test-Err:0.311 Test-Acc:0.8524
#  I:81 Train-Err:0.034 Train-Acc:0.998 Test-Err:0.311 Test-Acc:0.8534
#  I:82 Train-Err:0.033 Train-Acc:0.998 Test-Err:0.312 Test-Acc:0.8519
#  I:83 Train-Err:0.033 Train-Acc:0.998 Test-Err:0.312 Test-Acc:0.8525
#  I:84 Train-Err:0.032 Train-Acc:0.998 Test-Err:0.312 Test-Acc:0.8528
#  I:85 Train-Err:0.032 Train-Acc:0.998 Test-Err:0.313 Test-Acc:0.8518
#  I:86 Train-Err:0.031 Train-Acc:0.998 Test-Err:0.313 Test-Acc:0.8521
#  I:87 Train-Err:0.031 Train-Acc:0.998 Test-Err:0.313 Test-Acc:0.8513
#  I:88 Train-Err:0.030 Train-Acc:0.998 Test-Err:0.314 Test-Acc:0.8509
#  I:89 Train-Err:0.030 Train-Acc:0.998 Test-Err:0.314 Test-Acc:0.851
#  I:90 Train-Err:0.030 Train-Acc:0.998 Test-Err:0.314 Test-Acc:0.8513
#  I:91 Train-Err:0.029 Train-Acc:0.998 Test-Err:0.315 Test-Acc:0.8509
#  I:92 Train-Err:0.029 Train-Acc:0.998 Test-Err:0.315 Test-Acc:0.8513
#  I:93 Train-Err:0.028 Train-Acc:0.998 Test-Err:0.316 Test-Acc:0.8506
#  I:94 Train-Err:0.028 Train-Acc:0.998 Test-Err:0.316 Test-Acc:0.8509
#  I:95 Train-Err:0.028 Train-Acc:0.998 Test-Err:0.316 Test-Acc:0.8498
#  I:96 Train-Err:0.027 Train-Acc:0.998 Test-Err:0.316 Test-Acc:0.8508
#  I:97 Train-Err:0.027 Train-Acc:0.998 Test-Err:0.317 Test-Acc:0.8499
#  I:98 Train-Err:0.027 Train-Acc:0.998 Test-Err:0.317 Test-Acc:0.85
#  I:99 Train-Err:0.026 Train-Acc:0.998 Test-Err:0.318 Test-Acc:0.849
#  I:100 Train-Err:0.026 Train-Acc:0.998 Test-Err:0.318 Test-Acc:0.8505
#  I:101 Train-Err:0.026 Train-Acc:0.998 Test-Err:0.318 Test-Acc:0.8494
#  I:102 Train-Err:0.025 Train-Acc:0.998 Test-Err:0.318 Test-Acc:0.85
#  I:103 Train-Err:0.025 Train-Acc:0.998 Test-Err:0.319 Test-Acc:0.8497
#  I:104 Train-Err:0.025 Train-Acc:0.998 Test-Err:0.319 Test-Acc:0.8493
#  I:105 Train-Err:0.024 Train-Acc:0.998 Test-Err:0.319 Test-Acc:0.8491
#  I:106 Train-Err:0.024 Train-Acc:0.998 Test-Err:0.319 Test-Acc:0.8489
#  I:107 Train-Err:0.024 Train-Acc:0.998 Test-Err:0.320 Test-Acc:0.8486
#  I:108 Train-Err:0.023 Train-Acc:0.998 Test-Err:0.320 Test-Acc:0.8484
#  I:109 Train-Err:0.023 Train-Acc:0.998 Test-Err:0.320 Test-Acc:0.8482
#  I:110 Train-Err:0.023 Train-Acc:0.998 Test-Err:0.321 Test-Acc:0.8491
#  I:111 Train-Err:0.023 Train-Acc:0.998 Test-Err:0.321 Test-Acc:0.8481
#  I:112 Train-Err:0.022 Train-Acc:0.998 Test-Err:0.321 Test-Acc:0.8477
#  I:113 Train-Err:0.022 Train-Acc:0.998 Test-Err:0.321 Test-Acc:0.8485
#  I:114 Train-Err:0.022 Train-Acc:0.998 Test-Err:0.322 Test-Acc:0.8479
#  I:115 Train-Err:0.021 Train-Acc:0.998 Test-Err:0.322 Test-Acc:0.8472
#  I:116 Train-Err:0.021 Train-Acc:0.998 Test-Err:0.322 Test-Acc:0.8472
#  I:117 Train-Err:0.021 Train-Acc:0.998 Test-Err:0.323 Test-Acc:0.8465
#  I:118 Train-Err:0.021 Train-Acc:0.998 Test-Err:0.323 Test-Acc:0.8469
#  I:119 Train-Err:0.020 Train-Acc:0.998 Test-Err:0.323 Test-Acc:0.8466
#  I:120 Train-Err:0.020 Train-Acc:0.998 Test-Err:0.323 Test-Acc:0.8467
#  I:121 Train-Err:0.020 Train-Acc:0.998 Test-Err:0.323 Test-Acc:0.8449
#  I:122 Train-Err:0.020 Train-Acc:0.998 Test-Err:0.324 Test-Acc:0.8457
#  I:123 Train-Err:0.019 Train-Acc:0.998 Test-Err:0.324 Test-Acc:0.8455
#  I:124 Train-Err:0.019 Train-Acc:0.998 Test-Err:0.324 Test-Acc:0.8446
#  I:125 Train-Err:0.019 Train-Acc:0.998 Test-Err:0.324 Test-Acc:0.8449
#  I:126 Train-Err:0.019 Train-Acc:0.998 Test-Err:0.325 Test-Acc:0.8439
#  I:127 Train-Err:0.019 Train-Acc:0.998 Test-Err:0.325 Test-Acc:0.8442
#  I:128 Train-Err:0.018 Train-Acc:0.998 Test-Err:0.325 Test-Acc:0.8441
#  I:129 Train-Err:0.018 Train-Acc:0.998 Test-Err:0.325 Test-Acc:0.8441
#  I:130 Train-Err:0.018 Train-Acc:0.998 Test-Err:0.326 Test-Acc:0.8445
#  I:131 Train-Err:0.018 Train-Acc:0.998 Test-Err:0.326 Test-Acc:0.8439
#  I:132 Train-Err:0.018 Train-Acc:0.998 Test-Err:0.326 Test-Acc:0.8444
#  I:133 Train-Err:0.017 Train-Acc:0.998 Test-Err:0.326 Test-Acc:0.8441
#  I:134 Train-Err:0.017 Train-Acc:0.998 Test-Err:0.327 Test-Acc:0.8442
#  I:135 Train-Err:0.017 Train-Acc:0.998 Test-Err:0.327 Test-Acc:0.8434
#  I:136 Train-Err:0.017 Train-Acc:0.998 Test-Err:0.327 Test-Acc:0.844
#  I:137 Train-Err:0.017 Train-Acc:0.998 Test-Err:0.327 Test-Acc:0.8451
#  I:138 Train-Err:0.016 Train-Acc:0.998 Test-Err:0.327 Test-Acc:0.8442
#  I:139 Train-Err:0.016 Train-Acc:0.998 Test-Err:0.328 Test-Acc:0.8434
#  I:140 Train-Err:0.016 Train-Acc:0.998 Test-Err:0.327 Test-Acc:0.8437
#  I:141 Train-Err:0.016 Train-Acc:0.998 Test-Err:0.328 Test-Acc:0.8436
#  I:142 Train-Err:0.016 Train-Acc:0.998 Test-Err:0.328 Test-Acc:0.843
#  I:143 Train-Err:0.015 Train-Acc:0.998 Test-Err:0.328 Test-Acc:0.8436
#  I:144 Train-Err:0.015 Train-Acc:0.998 Test-Err:0.328 Test-Acc:0.8429
#  I:145 Train-Err:0.015 Train-Acc:0.998 Test-Err:0.329 Test-Acc:0.8428
#  I:146 Train-Err:0.015 Train-Acc:0.998 Test-Err:0.329 Test-Acc:0.8437
#  I:147 Train-Err:0.015 Train-Acc:0.998 Test-Err:0.329 Test-Acc:0.8428
#  I:148 Train-Err:0.015 Train-Acc:0.998 Test-Err:0.329 Test-Acc:0.843
#  I:149 Train-Err:0.014 Train-Acc:0.998 Test-Err:0.329 Test-Acc:0.8428
#  I:150 Train-Err:0.014 Train-Acc:0.998 Test-Err:0.329 Test-Acc:0.8427
#  I:151 Train-Err:0.014 Train-Acc:0.998 Test-Err:0.330 Test-Acc:0.8421
#  I:152 Train-Err:0.014 Train-Acc:0.998 Test-Err:0.329 Test-Acc:0.8421
#  I:153 Train-Err:0.014 Train-Acc:0.998 Test-Err:0.330 Test-Acc:0.8414
#  I:154 Train-Err:0.014 Train-Acc:0.998 Test-Err:0.330 Test-Acc:0.8421
#  I:155 Train-Err:0.014 Train-Acc:0.998 Test-Err:0.330 Test-Acc:0.842
#  I:156 Train-Err:0.013 Train-Acc:0.998 Test-Err:0.331 Test-Acc:0.8415
#  I:157 Train-Err:0.013 Train-Acc:0.998 Test-Err:0.331 Test-Acc:0.8424
#  I:158 Train-Err:0.013 Train-Acc:0.998 Test-Err:0.331 Test-Acc:0.8421
#  I:159 Train-Err:0.013 Train-Acc:0.998 Test-Err:0.331 Test-Acc:0.841
#  I:160 Train-Err:0.013 Train-Acc:0.998 Test-Err:0.331 Test-Acc:0.8414
#  I:161 Train-Err:0.013 Train-Acc:0.998 Test-Err:0.331 Test-Acc:0.8418
#  I:162 Train-Err:0.013 Train-Acc:0.998 Test-Err:0.332 Test-Acc:0.8405
#  I:163 Train-Err:0.012 Train-Acc:0.998 Test-Err:0.332 Test-Acc:0.8416
#  I:164 Train-Err:0.012 Train-Acc:0.998 Test-Err:0.332 Test-Acc:0.8412
#  I:165 Train-Err:0.012 Train-Acc:0.998 Test-Err:0.332 Test-Acc:0.8401
#  I:166 Train-Err:0.012 Train-Acc:0.998 Test-Err:0.332 Test-Acc:0.8407
#  I:167 Train-Err:0.012 Train-Acc:0.998 Test-Err:0.333 Test-Acc:0.8407
#  I:168 Train-Err:0.012 Train-Acc:0.998 Test-Err:0.333 Test-Acc:0.8402
#  I:169 Train-Err:0.012 Train-Acc:0.998 Test-Err:0.333 Test-Acc:0.8407
#  I:170 Train-Err:0.012 Train-Acc:0.998 Test-Err:0.333 Test-Acc:0.8405
#  I:171 Train-Err:0.011 Train-Acc:0.998 Test-Err:0.333 Test-Acc:0.8398
#  I:172 Train-Err:0.011 Train-Acc:0.998 Test-Err:0.333 Test-Acc:0.8403
#  I:173 Train-Err:0.011 Train-Acc:0.998 Test-Err:0.334 Test-Acc:0.8401
#  I:174 Train-Err:0.011 Train-Acc:0.998 Test-Err:0.334 Test-Acc:0.8394
#  I:175 Train-Err:0.011 Train-Acc:0.998 Test-Err:0.334 Test-Acc:0.8396
#  I:176 Train-Err:0.011 Train-Acc:0.998 Test-Err:0.334 Test-Acc:0.8394
#  I:177 Train-Err:0.011 Train-Acc:0.998 Test-Err:0.334 Test-Acc:0.8395
#  I:178 Train-Err:0.011 Train-Acc:0.998 Test-Err:0.335 Test-Acc:0.8397
#  I:179 Train-Err:0.011 Train-Acc:0.998 Test-Err:0.335 Test-Acc:0.8393
#  I:180 Train-Err:0.010 Train-Acc:0.998 Test-Err:0.335 Test-Acc:0.839
#  I:181 Train-Err:0.010 Train-Acc:0.998 Test-Err:0.335 Test-Acc:0.8383
#  I:182 Train-Err:0.010 Train-Acc:0.998 Test-Err:0.335 Test-Acc:0.8389
#  I:183 Train-Err:0.010 Train-Acc:0.998 Test-Err:0.335 Test-Acc:0.8382
#  I:184 Train-Err:0.010 Train-Acc:0.999 Test-Err:0.336 Test-Acc:0.8388
#  I:185 Train-Err:0.010 Train-Acc:0.999 Test-Err:0.336 Test-Acc:0.8386
#  I:186 Train-Err:0.010 Train-Acc:0.999 Test-Err:0.336 Test-Acc:0.8378
#  I:187 Train-Err:0.010 Train-Acc:0.999 Test-Err:0.336 Test-Acc:0.8386
#  I:188 Train-Err:0.010 Train-Acc:0.999 Test-Err:0.336 Test-Acc:0.8384
#  I:189 Train-Err:0.010 Train-Acc:0.999 Test-Err:0.337 Test-Acc:0.838
#  I:190 Train-Err:0.009 Train-Acc:0.999 Test-Err:0.337 Test-Acc:0.8377
#  I:191 Train-Err:0.009 Train-Acc:0.999 Test-Err:0.337 Test-Acc:0.8379
#  I:192 Train-Err:0.009 Train-Acc:0.999 Test-Err:0.337 Test-Acc:0.8379
#  I:193 Train-Err:0.009 Train-Acc:0.999 Test-Err:0.337 Test-Acc:0.8375
#  I:194 Train-Err:0.009 Train-Acc:0.999 Test-Err:0.337 Test-Acc:0.8378
#  I:195 Train-Err:0.009 Train-Acc:0.999 Test-Err:0.337 Test-Acc:0.8379
#  I:196 Train-Err:0.009 Train-Acc:0.999 Test-Err:0.338 Test-Acc:0.8378
#  I:197 Train-Err:0.009 Train-Acc:0.999 Test-Err:0.338 Test-Acc:0.8369
#  I:198 Train-Err:0.009 Train-Acc:0.999 Test-Err:0.338 Test-Acc:0.8379
#  I:199 Train-Err:0.009 Train-Acc:0.999 Test-Err:0.338 Test-Acc:0.8379
#  I:200 Train-Err:0.009 Train-Acc:0.999 Test-Err:0.338 Test-Acc:0.8368
#  I:201 Train-Err:0.009 Train-Acc:0.999 Test-Err:0.339 Test-Acc:0.8375
#  I:202 Train-Err:0.008 Train-Acc:0.999 Test-Err:0.339 Test-Acc:0.8372
#  I:203 Train-Err:0.008 Train-Acc:0.999 Test-Err:0.339 Test-Acc:0.8367
#  I:204 Train-Err:0.008 Train-Acc:0.999 Test-Err:0.339 Test-Acc:0.8362
#  I:205 Train-Err:0.008 Train-Acc:0.999 Test-Err:0.339 Test-Acc:0.8368
#  I:206 Train-Err:0.008 Train-Acc:0.999 Test-Err:0.339 Test-Acc:0.8368
#  I:207 Train-Err:0.008 Train-Acc:0.999 Test-Err:0.339 Test-Acc:0.8369
#  I:208 Train-Err:0.008 Train-Acc:0.999 Test-Err:0.340 Test-Acc:0.836
#  I:209 Train-Err:0.008 Train-Acc:0.999 Test-Err:0.340 Test-Acc:0.8362
#  I:210 Train-Err:0.008 Train-Acc:0.999 Test-Err:0.340 Test-Acc:0.8365
#  I:211 Train-Err:0.008 Train-Acc:0.999 Test-Err:0.340 Test-Acc:0.8356
#  I:212 Train-Err:0.008 Train-Acc:0.999 Test-Err:0.340 Test-Acc:0.8366
#  I:213 Train-Err:0.008 Train-Acc:0.999 Test-Err:0.340 Test-Acc:0.8367
#  I:214 Train-Err:0.008 Train-Acc:0.999 Test-Err:0.340 Test-Acc:0.8364
#  I:215 Train-Err:0.008 Train-Acc:0.999 Test-Err:0.341 Test-Acc:0.8355
#  I:216 Train-Err:0.007 Train-Acc:0.999 Test-Err:0.341 Test-Acc:0.8363
#  I:217 Train-Err:0.007 Train-Acc:0.999 Test-Err:0.341 Test-Acc:0.836
#  I:218 Train-Err:0.007 Train-Acc:0.999 Test-Err:0.341 Test-Acc:0.8358
#  I:219 Train-Err:0.007 Train-Acc:0.999 Test-Err:0.341 Test-Acc:0.8358
#  I:220 Train-Err:0.007 Train-Acc:0.999 Test-Err:0.341 Test-Acc:0.8356
#  I:221 Train-Err:0.007 Train-Acc:0.999 Test-Err:0.341 Test-Acc:0.8353
#  I:222 Train-Err:0.007 Train-Acc:0.999 Test-Err:0.342 Test-Acc:0.8353
#  I:223 Train-Err:0.007 Train-Acc:0.999 Test-Err:0.342 Test-Acc:0.8347
#  I:224 Train-Err:0.007 Train-Acc:0.999 Test-Err:0.342 Test-Acc:0.835
#  I:225 Train-Err:0.007 Train-Acc:0.999 Test-Err:0.342 Test-Acc:0.835
#  I:226 Train-Err:0.007 Train-Acc:0.999 Test-Err:0.342 Test-Acc:0.8352
#  I:227 Train-Err:0.007 Train-Acc:0.999 Test-Err:0.342 Test-Acc:0.8353
#  I:228 Train-Err:0.007 Train-Acc:0.999 Test-Err:0.343 Test-Acc:0.8343
#  I:229 Train-Err:0.007 Train-Acc:0.999 Test-Err:0.343 Test-Acc:0.8349
#  I:230 Train-Err:0.007 Train-Acc:0.999 Test-Err:0.343 Test-Acc:0.8346
#  I:231 Train-Err:0.007 Train-Acc:0.999 Test-Err:0.343 Test-Acc:0.8347
#  I:232 Train-Err:0.007 Train-Acc:0.999 Test-Err:0.343 Test-Acc:0.8348
#  I:233 Train-Err:0.007 Train-Acc:0.999 Test-Err:0.343 Test-Acc:0.8346
#  I:234 Train-Err:0.006 Train-Acc:0.999 Test-Err:0.343 Test-Acc:0.8348
#  I:235 Train-Err:0.006 Train-Acc:0.999 Test-Err:0.343 Test-Acc:0.834
#  I:236 Train-Err:0.006 Train-Acc:0.999 Test-Err:0.344 Test-Acc:0.8345
#  I:237 Train-Err:0.006 Train-Acc:0.999 Test-Err:0.344 Test-Acc:0.8343
#  I:238 Train-Err:0.006 Train-Acc:0.999 Test-Err:0.344 Test-Acc:0.834
#  I:239 Train-Err:0.006 Train-Acc:0.999 Test-Err:0.344 Test-Acc:0.8344
#  I:240 Train-Err:0.006 Train-Acc:0.999 Test-Err:0.344 Test-Acc:0.8344
#  I:241 Train-Err:0.006 Train-Acc:0.999 Test-Err:0.344 Test-Acc:0.8342
#  I:242 Train-Err:0.006 Train-Acc:0.999 Test-Err:0.344 Test-Acc:0.834
#  I:243 Train-Err:0.006 Train-Acc:0.999 Test-Err:0.345 Test-Acc:0.8338
#  I:244 Train-Err:0.006 Train-Acc:0.999 Test-Err:0.345 Test-Acc:0.8346
#  I:245 Train-Err:0.006 Train-Acc:0.999 Test-Err:0.345 Test-Acc:0.8341
#  I:246 Train-Err:0.006 Train-Acc:0.999 Test-Err:0.345 Test-Acc:0.834
#  I:247 Train-Err:0.006 Train-Acc:0.999 Test-Err:0.345 Test-Acc:0.8335
#  I:248 Train-Err:0.006 Train-Acc:0.999 Test-Err:0.345 Test-Acc:0.8334
#  I:249 Train-Err:0.006 Train-Acc:0.999 Test-Err:0.345 Test-Acc:0.8337
#  I:250 Train-Err:0.006 Train-Acc:0.999 Test-Err:0.345 Test-Acc:0.8336
#  I:251 Train-Err:0.006 Train-Acc:0.999 Test-Err:0.345 Test-Acc:0.8335
#  I:252 Train-Err:0.006 Train-Acc:0.999 Test-Err:0.346 Test-Acc:0.8339
#  I:253 Train-Err:0.006 Train-Acc:0.999 Test-Err:0.346 Test-Acc:0.8336
#  I:254 Train-Err:0.006 Train-Acc:0.999 Test-Err:0.346 Test-Acc:0.834
#  I:255 Train-Err:0.006 Train-Acc:0.999 Test-Err:0.346 Test-Acc:0.8338
#  I:256 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.346 Test-Acc:0.834
#  I:257 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.346 Test-Acc:0.8336
#  I:258 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.346 Test-Acc:0.8338
#  I:259 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.347 Test-Acc:0.8334
#  I:260 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.347 Test-Acc:0.8342
#  I:261 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.347 Test-Acc:0.8337
#  I:262 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.347 Test-Acc:0.8332
#  I:263 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.347 Test-Acc:0.8338
#  I:264 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.347 Test-Acc:0.8334
#  I:265 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.347 Test-Acc:0.8329
#  I:266 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.347 Test-Acc:0.8334
#  I:267 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.347 Test-Acc:0.8333
#  I:268 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.347 Test-Acc:0.833
#  I:269 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.348 Test-Acc:0.8329
#  I:270 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.348 Test-Acc:0.8332
#  I:271 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.348 Test-Acc:0.8327
#  I:272 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.348 Test-Acc:0.8325
#  I:273 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.348 Test-Acc:0.833
#  I:274 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.348 Test-Acc:0.8331
#  I:275 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.348 Test-Acc:0.833
#  I:276 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.348 Test-Acc:0.8328
#  I:277 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.348 Test-Acc:0.8329
#  I:278 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.349 Test-Acc:0.8323
#  I:279 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.349 Test-Acc:0.833
#  I:280 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.349 Test-Acc:0.8326
#  I:281 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.349 Test-Acc:0.8324
#  I:282 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.349 Test-Acc:0.8327
#  I:283 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.349 Test-Acc:0.8324
#  I:284 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.349 Test-Acc:0.8328
#  I:285 Train-Err:0.005 Train-Acc:0.999 Test-Err:0.349 Test-Acc:0.8322
#  I:286 Train-Err:0.004 Train-Acc:0.999 Test-Err:0.349 Test-Acc:0.8328
#  I:287 Train-Err:0.004 Train-Acc:0.999 Test-Err:0.350 Test-Acc:0.8324
#  I:288 Train-Err:0.004 Train-Acc:0.999 Test-Err:0.350 Test-Acc:0.8323
#  I:289 Train-Err:0.004 Train-Acc:0.999 Test-Err:0.350 Test-Acc:0.832
#  I:290 Train-Err:0.004 Train-Acc:0.999 Test-Err:0.350 Test-Acc:0.832
#  I:291 Train-Err:0.004 Train-Acc:0.999 Test-Err:0.350 Test-Acc:0.8316
#  I:292 Train-Err:0.004 Train-Acc:0.999 Test-Err:0.350 Test-Acc:0.832
#  I:293 Train-Err:0.004 Train-Acc:0.999 Test-Err:0.350 Test-Acc:0.8316
#  I:294 Train-Err:0.004 Train-Acc:0.999 Test-Err:0.350 Test-Acc:0.8321
#  I:295 Train-Err:0.004 Train-Acc:0.999 Test-Err:0.350 Test-Acc:0.8316
#  I:296 Train-Err:0.004 Train-Acc:0.999 Test-Err:0.350 Test-Acc:0.8318
#  I:297 Train-Err:0.004 Train-Acc:0.999 Test-Err:0.351 Test-Acc:0.8315
#  I:298 Train-Err:0.004 Train-Acc:0.999 Test-Err:0.351 Test-Acc:0.8314
#  I:299 Train-Err:0.004 Train-Acc:0.999 Test-Err:0.351 Test-Acc:0.8316
