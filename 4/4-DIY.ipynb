# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /Users/daisuke.inoue/.pyenv/versions/3.13.2/lib/python3.13/site-packages (2.5.1)

# %%
import numpy as np

# %%
input = 2
goal_prediction = 0.8
weight = 0.5

alpha = 0.1

for iteration in range(20):
    prediction = input * weight

    error = (prediction - goal_prediction) ** 2
    delta = prediction - goal_prediction

    derivative = input * delta
    weight = weight - ( alpha * derivative )
    print("Iteration:" + str(iteration) + " Error:" + str(error) + " Prediction:" + str(prediction) + " Weight:" + str(weight))
# Out:
# Iteration:0 Error:0.03999999999999998 Prediction:1.0 Weight:0.46
# Iteration:1 Error:0.0144 Prediction:0.92 Weight:0.436
# Iteration:2 Error:0.005183999999999993 Prediction:0.872 Weight:0.42160000000000003
# Iteration:3 Error:0.0018662400000000014 Prediction:0.8432000000000001 Weight:0.41296000000000005
# Iteration:4 Error:0.0006718464000000028 Prediction:0.8259200000000001 Weight:0.407776
# Iteration:5 Error:0.00024186470400000033 Prediction:0.815552 Weight:0.4046656
# Iteration:6 Error:8.70712934399997e-05 Prediction:0.8093312 Weight:0.40279936
# Iteration:7 Error:3.134566563839939e-05 Prediction:0.80559872 Weight:0.401679616
# Iteration:8 Error:1.1284439629823931e-05 Prediction:0.803359232 Weight:0.4010077696
# Iteration:9 Error:4.062398266736526e-06 Prediction:0.8020155392 Weight:0.40060466176000004
# Iteration:10 Error:1.4624633760252567e-06 Prediction:0.8012093235200001 Weight:0.40036279705600003
# Iteration:11 Error:5.264868153690924e-07 Prediction:0.8007255941120001 Weight:0.40021767823360005
# Iteration:12 Error:1.8953525353291194e-07 Prediction:0.8004353564672001 Weight:0.40013060694016006
# Iteration:13 Error:6.82326912718715e-08 Prediction:0.8002612138803201 Weight:0.40007836416409603
# Iteration:14 Error:2.456376885786678e-08 Prediction:0.8001567283281921 Weight:0.40004701849845764
# Iteration:15 Error:8.842956788836216e-09 Prediction:0.8000940369969153 Weight:0.4000282110990746
# Iteration:16 Error:3.1834644439835434e-09 Prediction:0.8000564221981492 Weight:0.40001692665944477
# Iteration:17 Error:1.1460471998340758e-09 Prediction:0.8000338533188895 Weight:0.40001015599566686
# Iteration:18 Error:4.125769919393652e-10 Prediction:0.8000203119913337 Weight:0.40000609359740014
# Iteration:19 Error:1.485277170987127e-10 Prediction:0.8000121871948003 Weight:0.4000036561584401
